# %% [markdown]
# # Task 4 - Analysis
#
# ## Question 1
# From Task 3 Step 1, analyze how the national background of those arrested changed before and after the start of the second Trump administration, broken down by ICE Area of Responsibility (AOR).

# %% [markdown]
# ### 0- Setup

# %%
from pathlib import Path
from datetime import datetime, timedelta

import numpy as np
import pandas as pd
import altair as alt

import process_data

# %%
pd.set_option("display.max_rows", 300)
pd.set_option("display.max_columns", 200)

# %%
arrests_filename = 'arrests_with_facility_county.csv'
cwd = Path.cwd()
root = cwd.parent
data = root / "data"
figures = root / "figures"

# %%
arrests_df = pd.read_csv(data/arrests_filename, parse_dates=['apprehension_date','departed_date'])

# %%
arrests_df.head()
# Out:
#     apprehension_date apprehension_state                   apprehension_aor  \
# 0 2024-08-07 09:43:00           VIRGINIA  WASHINGTON AREA OF RESPONSIBILITY
# 1 2024-10-19 08:33:00              TEXAS     HOUSTON AREA OF RESPONSIBILITY
# 2 2025-04-15 10:08:00         NEW JERSEY      NEWARK AREA OF RESPONSIBILITY
# 3 2025-06-03 09:20:00          MINNESOTA    ST. PAUL AREA OF RESPONSIBILITY
# 4 2025-01-21 05:41:00                NaN       MIAMI AREA OF RESPONSIBILITY
#
#                 final_program        apprehension_method  \
# 0  ERO CRIMINAL ALIEN PROGRAM       NON-CUSTODIAL ARREST
# 1  ERO CRIMINAL ALIEN PROGRAM    CAP LOCAL INCARCERATION
# 2  ERO CRIMINAL ALIEN PROGRAM  CAP FEDERAL INCARCERATION
# 3         FUGITIVE OPERATIONS       NON-CUSTODIAL ARREST
# 4  ERO CRIMINAL ALIEN PROGRAM    CAP LOCAL INCARCERATION
#
#        apprehension_criminality                           case_status  \
# 0          1 CONVICTED CRIMINAL  8-EXCLUDED/REMOVED - INADMISSIBILITY
# 1          1 CONVICTED CRIMINAL    6-DEPORTED/REMOVED - DEPORTABILITY
# 2          1 CONVICTED CRIMINAL  8-EXCLUDED/REMOVED - INADMISSIBILITY
# 3  3 OTHER IMMIGRATION VIOLATOR                                ACTIVE
# 4    2 PENDING CRIMINAL CHARGES       3-VOLUNTARY DEPARTURE CONFIRMED
#
#                                        case_category departed_date  \
# 0                        [16] REINSTATED FINAL ORDER    2024-08-19
# 1                        [16] REINSTATED FINAL ORDER    2024-10-22
# 2                        [16] REINSTATED FINAL ORDER    2025-06-10
# 3    [8G] EXPEDITED REMOVAL - CREDIBLE FEAR REFERRAL           NaT
# 4  [8C] EXCLUDABLE / INADMISSIBLE - ADMINISTRATIV...    2025-02-01
#
#     departure_country final_order_yes_no  birth_year citizenship_country  \
# 0            HONDURAS                YES        1981            HONDURAS
# 1              MEXICO                YES        1984              MEXICO
# 2  DOMINICAN REPUBLIC                YES        1988  DOMINICAN REPUBLIC
# 3                 NaN                YES        1985            COLOMBIA
# 4              MEXICO                YES        1983              MEXICO
#
#    gender                         apprehension_site_landmark  \
# 0    MALE                     HBG GENERAL AREA, NON-SPECIFIC
# 1    MALE                    HARRIS COUNTY JAIL, HOUSTON, TX
# 2    MALE                          FORT DIX EAST, NEW JERSEY
# 3  FEMALE                     SPM GENERAL AREA, NON-SPECIFIC
# 4    MALE  MIAMI DADE COUNTY JAIL TURNER GUILFORD KNIGHT ...
#
#                           unique_identifier                     county  \
# 0  0000b34edd657d516c02b13a7c352d62d0effcb6                        NaN
# 1  0000ba6e459998a6046d185d82cf4349de1479d0  HARRIS COUNTY HOUSTON, TX
# 2  0000c3d23fb0e444864559575900d410c4e8490f                        NaN
# 3  0000d3dbf8033b5f209f6547ffee5b84feb4f599                        NaN
# 4  000104d730bf021326c6dc0deb3dd575304136b5                        NaN
#
#                      jail prison                facility  \
# 0                     NaN    NaN                     NaN
# 1      HARRIS COUNTY JAIL    NaN      HARRIS COUNTY JAIL
# 2                     NaN    NaN                     NaN
# 3                     NaN    NaN                     NaN
# 4  MIAMI DADE COUNTY JAIL    NaN  MIAMI DADE COUNTY JAIL
#
#   other_facility_loc_info
# 0                     NaN
# 1             HOUSTON, TX
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %% [markdown]
# **Note** - saving df as csv (from task 2) has also messed up times in the datetime - must be something in the excel format. Can look to change in future if we need times

# %% [markdown]
# ### 1- Data exploration and processing
#
# **Key info:**
# * Trump was inaugerated on 20th January 2025
#
# **Dates approach:**
# * Will likely want to look at month totals to smooth out -> create month var
# * More data pre Trump, so will want to do some analysis looking at same number of days/months pre and post (for overall numbers/proportions etc.)
#
# **National background approach:**
# * Have the number of citizenship countries changed?
# * What about the specific countries - what has changed about them?
#    * Add in continent?
#    * Any other country meta data to add in?
# * Is this different depending on ICE Area of Responsibility (AOR)?

# %% [markdown]
# ##### ICE Area of Responsibilitiy (AOR)

# %%
arrests_df['apprehension_aor'].value_counts(dropna=False)
# Out:
# apprehension_aor
# MIAMI AREA OF RESPONSIBILITY             26925
# NEW ORLEANS AREA OF RESPONSIBILITY       23598
# DALLAS AREA OF RESPONSIBILITY            23185
# HOUSTON AREA OF RESPONSIBILITY           21785
# CHICAGO AREA OF RESPONSIBILITY           18370
# ATLANTA AREA OF RESPONSIBILITY           16596
# SAN ANTONIO AREA OF RESPONSIBILITY       15161
# HARLINGEN AREA OF RESPONSIBILITY         11607
# LOS ANGELES AREA OF RESPONSIBILITY       11575
# NEWARK AREA OF RESPONSIBILITY             8506
# PHOENIX AREA OF RESPONSIBILITY            8351
# NEW YORK CITY AREA OF RESPONSIBILITY      8101
# SALT LAKE CITY AREA OF RESPONSIBILITY     7664
# BOSTON AREA OF RESPONSIBILITY             7148
# WASHINGTON AREA OF RESPONSIBILITY         6955
# PHILADELPHIA AREA OF RESPONSIBILITY       6240
# ST. PAUL AREA OF RESPONSIBILITY           6124
# NaN                                       5903
# DETROIT AREA OF RESPONSIBILITY            5400
# SAN FRANCISCO AREA OF RESPONSIBILITY      5277
# DENVER AREA OF RESPONSIBILITY             4582
# EL PASO AREA OF RESPONSIBILITY            4383
# BALTIMORE AREA OF RESPONSIBILITY          3756
# SEATTLE AREA OF RESPONSIBILITY            3669
# BUFFALO AREA OF RESPONSIBILITY            2200
# SAN DIEGO AREA OF RESPONSIBILITY          2132
# HQ AREA OF RESPONSIBILITY                   33
# Name: count, dtype: int64

# %%
arrests_df['apprehension_aor'].fillna('MISSING', inplace = True) 
# done because I don't want to lose these from the analysis, there may be a reason that AOR is missing

# %% [markdown]
# ##### Citizenship country

# %%
arrests_df['citizenship_country'].isna().sum()
# Out:
# 0

# %%
arrests_df['citizenship_country'].value_counts().reset_index().head(10)
# Out:
#   citizenship_country   count
# 0              MEXICO  101036
# 1           GUATEMALA   32638
# 2            HONDURAS   29628
# 3           VENEZUELA   15238
# 4           NICARAGUA   14688
# 5         EL SALVADOR   12041
# 6            COLOMBIA    9943
# 7             ECUADOR    9339
# 8                CUBA    6205
# 9  DOMINICAN REPUBLIC    5065

# %% [markdown]
# ##### Adding continent info
#
# **Note** this is a clunky, quick way to do this just to see whether it is something to include in the analysis. In the next steps of this analysis it would be good to bring in additional country information, and think about what geographic area is interesting (e.g. instead of contintent we could use slightly corser geographic areas that are meaningful, such as "Western Asia", "Central America" etc.)

# %%
continent_dict = {
    'NORTH AND CENTRAL AMERICA': [
        'TURKS AND CAICOS ISLANDS','TRINIDAD AND TOBAGO','ST. VINCENT-GRENADINES', 'ST. LUCIA','ST. KITTS-NEVIS',
        'SINT EUSTATIUS', 'SINT MAARTEN(DUTCH)', 'PANAMA','NICARAGUA','NETHERLANDS ANTILLES', 'MONTSERRAT','MEXICO',
        'JAMAICA','HAITI', 'HONDURAS','GRENADA', 'GUADELOUPE', 'GUATEMALA','CURACAO','CANADA', 'ANGUILLA','ANTIGUA-BARBUDA',
        'BAHAMAS', 'BARBADOS', 'BELIZE','BOLIVIA','COSTA RICA','CUBA','DOMINICA', 'DOMINICAN REPUBLIC','EL SALVADOR','BRITISH VIRGIN ISLANDS'
    ],
     'SOUTH AMERICA': [
        'VENEZUELA','URUGUAY','SURINAME','PERU','PARAGUAY','GUYANA','FRENCH GUIANA','ECUADOR','COLOMBIA', 'CHILE','BRAZIL','ARGENTINA'
    ],
     'EUROPE': [
        'YUGOSLAVIA','USSR','UNITED KINGDOM','UKRAINE','SWITZERLAND','SWEDEN','SPAIN','SLOVENIA','SLOVAKIA', 'SERBIA AND MONTENEGRO','SERBIA',
        'RUSSIA','ROMANIA','PORTUGAL','POLAND', 'NORWAY','NORTH MACEDONIA','NETHERLANDS','MONTENEGRO','MOLDOVA','MALTA','LITHUANIA','LATVIA',
        'KOSOVO','ITALY','IRELAND','ICELAND','HUNGARY', 'GREECE','GERMANY','FRANCE','FINLAND','ESTONIA','DENMARK','CZECHOSLOVAKIA','CZECH REPUBLIC',
        'CYPRUS','CROATIA','BULGARIA','BOSNIA-HERZEGOVINA','BELGIUM','BELARUS','AUSTRIA','ALBANIA', 'ANDORRA'
    ],
     'AFRICA': [
        'ZIMBABWE','ZAMBIA','UGANDA','TUNISIA','TOGO','TANZANIA','SUDAN','SOUTH SUDAN','SOUTH AFRICA','SOMALIA','SIERRA LEONE','SENEGAL',
        'SAO TOME AND PRINCIPE','RWANDA','NIGERIA','NIGER', 'NAMIBIA','MOZAMBIQUE','MOROCCO','MAURITIUS','MAURITANIA','MALI','LIBYA',
        'LIBERIA','KENYA','IVORY COAST','GUINEA', 'GUINEA-BISSAU','GHANA','GAMBIA','GABON','EGYPT','ETHIOPIA','ESWATINI','ERITREA','EQUATORIAL GUINEA',
        'DJIBOUTI','DEM REP OF THE CONGO','CONGO','CHAD','CENTRAL AFRICAN REPUBLIC','CAPE VERDE','CAMEROON','BURUNDI','BURKINA FASO','BOTSWANA',
        'BENIN','ANGOLA','ALGERIA'],
     'ASIA': [
        'YEMEN','VIETNAM','UZBEKISTAN','UNITED ARAB EMIRATES','TURKMENISTAN','TURKIYE','THAILAND','TAJIKISTAN','TAIWAN','SYRIA','SRI LANKA',
        'SOUTH KOREA','SAUDI ARABIA','PHILIPPINES','PAKISTAN','OMAN','NEPAL','MONGOLIA', 'MALAYSIA','MALAWI','LEBANON','LAOS','KYRGYZSTAN','KUWAIT',
        'KOREA','KAZAKHSTAN','JORDAN','JAPAN','ISRAEL','IRAQ','IRAN','INDONESIA', 'INDIA','HONG KONG', 'GEORGIA','EAST TIMOR','CHINA, PEOPLES REPUBLIC OF',
        'CAMBODIA','BURMA','BRUNEI','BHUTAN','BANGLADESH','BAHRAIN','AZERBAIJAN','ARMENIA', 'AFGHANISTAN'
    ],
     'OCEANIA': [
        'TONGA','SAMOA','PAPUA NEW GUINEA','PALAU','NEW ZEALAND','MICRONESIA, FEDERATED STATES OF','MARSHALL ISLANDS','FRENCH POLYNESIA',
        'FIJI', 'AUSTRALIA'
    ]}

# %%
country_continent_lookup = {}

for cont in continent_dict.keys():
    for coun in continent_dict[cont]:
        country_continent_lookup[coun] = cont

# %%
arrests_df['citizenship_continent'] = arrests_df['citizenship_country'].map(country_continent_lookup)

# %% [markdown]
# ##### Date vars

# %%
trump_inaugaration_date = datetime.strptime('2025-01-20','%Y-%m-%d').date()

# %%
arrests_df['trump_bool'] = np.where(
    arrests_df['apprehension_date'].dt.date >= trump_inaugaration_date, "trump", "pre_trump")

# %%
arrests_df['apprehension_month_year'] = arrests_df['apprehension_date'].dt.to_period('M')
arrests_df['apprehension_day'] = arrests_df['apprehension_date'].dt.date

# %% [markdown]
# **Note** - the below is a rough approach, taking the exact same number of days pre and post the trump inaugeration. In future steps of this research I would check this makes sense, and whether we need to take into account seasonality, day of week, holidays etc.

# %%
number_days_trump_administration = (arrests_df['apprehension_day'].max() - trump_inaugaration_date).days
start_date = trump_inaugaration_date - timedelta(number_days_trump_administration)

eq_days_pre_post_trump = arrests_df[arrests_df['apprehension_day'] >= start_date].copy()

# %%
# check equal:

(trump_inaugaration_date - start_date).days == (arrests_df['apprehension_day'].max() - trump_inaugaration_date).days
# Out:
# True

# %%
eq_days_pre_post_trump['trump_bool'].value_counts()
# Out:
# trump_bool
# trump        111567
# pre_trump     44648
# Name: count, dtype: int64

# %% [markdown]
# ### 2- Analysis

# %%
def get_summary_table(df, groupby_col='citizenship_country'):
    num_arrests_by_cc = df.groupby('trump_bool')[groupby_col].value_counts().reset_index().rename(columns={0:'number_arrests'})
    
    pivot_num_by_cc = num_arrests_by_cc.pivot(index=groupby_col, values='count', columns='trump_bool')

    pivot_num_by_cc['fact_increase'] = pivot_num_by_cc['trump'] / pivot_num_by_cc['pre_trump']
    pivot_num_by_cc['num_increase'] = pivot_num_by_cc['trump'] - pivot_num_by_cc['pre_trump']

    for c in ['pre_trump','trump']:
        pivot_num_by_cc[f'{c}_perc_arrests'] = (pivot_num_by_cc[c] / pivot_num_by_cc[c].sum()) * 100

    return pivot_num_by_cc

# %% [markdown]
# #### AOR:
#
# First looking to see which AORs have had the largest jump in numbers of arrests

# %%
get_summary_table(eq_days_pre_post_trump, 'apprehension_aor').sort_values(by='fact_increase', ascending=False)
# Out:
# trump_bool                             pre_trump  trump  fact_increase  \
# apprehension_aor
# SAN DIEGO AREA OF RESPONSIBILITY             241   1303       5.406639
# BOSTON AREA OF RESPONSIBILITY                879   3957       4.501706
# WASHINGTON AREA OF RESPONSIBILITY           1023   4068       3.976540
# DENVER AREA OF RESPONSIBILITY                661   2242       3.391831
# BUFFALO AREA OF RESPONSIBILITY               316   1057       3.344937
# DETROIT AREA OF RESPONSIBILITY               763   2503       3.280472
# PHILADELPHIA AREA OF RESPONSIBILITY         1004   3214       3.201195
# HQ AREA OF RESPONSIBILITY                      7     22       3.142857
# MIAMI AREA OF RESPONSIBILITY                4291  13345       3.109998
# ATLANTA AREA OF RESPONSIBILITY              2696   8330       3.089763
# NEW YORK CITY AREA OF RESPONSIBILITY         805   2426       3.013665
# LOS ANGELES AREA OF RESPONSIBILITY          1705   5106       2.994721
# SEATTLE AREA OF RESPONSIBILITY               437   1298       2.970252
# ST. PAUL AREA OF RESPONSIBILITY              921   2689       2.919653
# SALT LAKE CITY AREA OF RESPONSIBILITY       1262   3474       2.752773
# BALTIMORE AREA OF RESPONSIBILITY             693   1800       2.597403
# SAN FRANCISCO AREA OF RESPONSIBILITY         872   2168       2.486239
# SAN ANTONIO AREA OF RESPONSIBILITY          2479   5946       2.398548
# EL PASO AREA OF RESPONSIBILITY               793   1852       2.335435
# DALLAS AREA OF RESPONSIBILITY               4273   9159       2.143459
# PHOENIX AREA OF RESPONSIBILITY              1685   3532       2.096142
# NEW ORLEANS AREA OF RESPONSIBILITY          4725   9494       2.009312
# CHICAGO AREA OF RESPONSIBILITY              3385   6657       1.966617
# HOUSTON AREA OF RESPONSIBILITY              4425   8419       1.902599
# HARLINGEN AREA OF RESPONSIBILITY            2155   3903       1.811137
# NEWARK AREA OF RESPONSIBILITY               1714   3058       1.784131
#
# trump_bool                             num_increase  pre_trump_perc_arrests  \
# apprehension_aor
# SAN DIEGO AREA OF RESPONSIBILITY               1062                0.545126
# BOSTON AREA OF RESPONSIBILITY                  3078                1.988238
# WASHINGTON AREA OF RESPONSIBILITY              3045                2.313956
# DENVER AREA OF RESPONSIBILITY                  1581                1.495137
# BUFFALO AREA OF RESPONSIBILITY                  741                0.714770
# DETROIT AREA OF RESPONSIBILITY                 1740                1.725854
# PHILADELPHIA AREA OF RESPONSIBILITY            2210                2.270979
# HQ AREA OF RESPONSIBILITY                        15                0.015834
# MIAMI AREA OF RESPONSIBILITY                   9054                9.705949
# ATLANTA AREA OF RESPONSIBILITY                 5634                6.098168
# NEW YORK CITY AREA OF RESPONSIBILITY           1621                1.820855
# LOS ANGELES AREA OF RESPONSIBILITY             3401                3.856594
# SEATTLE AREA OF RESPONSIBILITY                  861                0.988464
# ST. PAUL AREA OF RESPONSIBILITY                1768                2.083239
# SALT LAKE CITY AREA OF RESPONSIBILITY          2212                2.854558
# BALTIMORE AREA OF RESPONSIBILITY               1107                1.567519
# SAN FRANCISCO AREA OF RESPONSIBILITY           1296                1.972404
# SAN ANTONIO AREA OF RESPONSIBILITY             3467                5.607329
# EL PASO AREA OF RESPONSIBILITY                 1059                1.793712
# DALLAS AREA OF RESPONSIBILITY                  4886                9.665234
# PHOENIX AREA OF RESPONSIBILITY                 1847                3.811355
# NEW ORLEANS AREA OF RESPONSIBILITY             4769               10.687627
# CHICAGO AREA OF RESPONSIBILITY                 3272                7.656639
# HOUSTON AREA OF RESPONSIBILITY                 3994               10.009048
# HARLINGEN AREA OF RESPONSIBILITY               1748                4.874463
# NEWARK AREA OF RESPONSIBILITY                  1344                3.876951
#
# trump_bool                             trump_perc_arrests
# apprehension_aor
# SAN DIEGO AREA OF RESPONSIBILITY                 1.173641
# BOSTON AREA OF RESPONSIBILITY                    3.564158
# WASHINGTON AREA OF RESPONSIBILITY                3.664139
# DENVER AREA OF RESPONSIBILITY                    2.019420
# BUFFALO AREA OF RESPONSIBILITY                   0.952064
# DETROIT AREA OF RESPONSIBILITY                   2.254508
# PHILADELPHIA AREA OF RESPONSIBILITY              2.894922
# HQ AREA OF RESPONSIBILITY                        0.019816
# MIAMI AREA OF RESPONSIBILITY                    12.020140
# ATLANTA AREA OF RESPONSIBILITY                   7.503017
# NEW YORK CITY AREA OF RESPONSIBILITY             2.185152
# LOS ANGELES AREA OF RESPONSIBILITY               4.599088
# SEATTLE AREA OF RESPONSIBILITY                   1.169138
# ST. PAUL AREA OF RESPONSIBILITY                  2.422042
# SALT LAKE CITY AREA OF RESPONSIBILITY            3.129110
# BALTIMORE AREA OF RESPONSIBILITY                 1.621300
# SAN FRANCISCO AREA OF RESPONSIBILITY             1.952766
# SAN ANTONIO AREA OF RESPONSIBILITY               5.355695
# EL PASO AREA OF RESPONSIBILITY                   1.668138
# DALLAS AREA OF RESPONSIBILITY                    8.249716
# PHOENIX AREA OF RESPONSIBILITY                   3.181351
# NEW ORLEANS AREA OF RESPONSIBILITY               8.551458
# CHICAGO AREA OF RESPONSIBILITY                   5.996109
# HOUSTON AREA OF RESPONSIBILITY                   7.583182
# HARLINGEN AREA OF RESPONSIBILITY                 3.515519
# NEWARK AREA OF RESPONSIBILITY                    2.754409

# %%
get_summary_table(eq_days_pre_post_trump, 'apprehension_aor').sort_values(by='num_increase', ascending=False)
# Out:
# trump_bool                             pre_trump  trump  fact_increase  \
# apprehension_aor
# MIAMI AREA OF RESPONSIBILITY                4291  13345       3.109998
# ATLANTA AREA OF RESPONSIBILITY              2696   8330       3.089763
# DALLAS AREA OF RESPONSIBILITY               4273   9159       2.143459
# NEW ORLEANS AREA OF RESPONSIBILITY          4725   9494       2.009312
# HOUSTON AREA OF RESPONSIBILITY              4425   8419       1.902599
# SAN ANTONIO AREA OF RESPONSIBILITY          2479   5946       2.398548
# LOS ANGELES AREA OF RESPONSIBILITY          1705   5106       2.994721
# CHICAGO AREA OF RESPONSIBILITY              3385   6657       1.966617
# BOSTON AREA OF RESPONSIBILITY                879   3957       4.501706
# WASHINGTON AREA OF RESPONSIBILITY           1023   4068       3.976540
# SALT LAKE CITY AREA OF RESPONSIBILITY       1262   3474       2.752773
# PHILADELPHIA AREA OF RESPONSIBILITY         1004   3214       3.201195
# PHOENIX AREA OF RESPONSIBILITY              1685   3532       2.096142
# ST. PAUL AREA OF RESPONSIBILITY              921   2689       2.919653
# HARLINGEN AREA OF RESPONSIBILITY            2155   3903       1.811137
# DETROIT AREA OF RESPONSIBILITY               763   2503       3.280472
# NEW YORK CITY AREA OF RESPONSIBILITY         805   2426       3.013665
# DENVER AREA OF RESPONSIBILITY                661   2242       3.391831
# NEWARK AREA OF RESPONSIBILITY               1714   3058       1.784131
# SAN FRANCISCO AREA OF RESPONSIBILITY         872   2168       2.486239
# BALTIMORE AREA OF RESPONSIBILITY             693   1800       2.597403
# SAN DIEGO AREA OF RESPONSIBILITY             241   1303       5.406639
# EL PASO AREA OF RESPONSIBILITY               793   1852       2.335435
# SEATTLE AREA OF RESPONSIBILITY               437   1298       2.970252
# BUFFALO AREA OF RESPONSIBILITY               316   1057       3.344937
# HQ AREA OF RESPONSIBILITY                      7     22       3.142857
#
# trump_bool                             num_increase  pre_trump_perc_arrests  \
# apprehension_aor
# MIAMI AREA OF RESPONSIBILITY                   9054                9.705949
# ATLANTA AREA OF RESPONSIBILITY                 5634                6.098168
# DALLAS AREA OF RESPONSIBILITY                  4886                9.665234
# NEW ORLEANS AREA OF RESPONSIBILITY             4769               10.687627
# HOUSTON AREA OF RESPONSIBILITY                 3994               10.009048
# SAN ANTONIO AREA OF RESPONSIBILITY             3467                5.607329
# LOS ANGELES AREA OF RESPONSIBILITY             3401                3.856594
# CHICAGO AREA OF RESPONSIBILITY                 3272                7.656639
# BOSTON AREA OF RESPONSIBILITY                  3078                1.988238
# WASHINGTON AREA OF RESPONSIBILITY              3045                2.313956
# SALT LAKE CITY AREA OF RESPONSIBILITY          2212                2.854558
# PHILADELPHIA AREA OF RESPONSIBILITY            2210                2.270979
# PHOENIX AREA OF RESPONSIBILITY                 1847                3.811355
# ST. PAUL AREA OF RESPONSIBILITY                1768                2.083239
# HARLINGEN AREA OF RESPONSIBILITY               1748                4.874463
# DETROIT AREA OF RESPONSIBILITY                 1740                1.725854
# NEW YORK CITY AREA OF RESPONSIBILITY           1621                1.820855
# DENVER AREA OF RESPONSIBILITY                  1581                1.495137
# NEWARK AREA OF RESPONSIBILITY                  1344                3.876951
# SAN FRANCISCO AREA OF RESPONSIBILITY           1296                1.972404
# BALTIMORE AREA OF RESPONSIBILITY               1107                1.567519
# SAN DIEGO AREA OF RESPONSIBILITY               1062                0.545126
# EL PASO AREA OF RESPONSIBILITY                 1059                1.793712
# SEATTLE AREA OF RESPONSIBILITY                  861                0.988464
# BUFFALO AREA OF RESPONSIBILITY                  741                0.714770
# HQ AREA OF RESPONSIBILITY                        15                0.015834
#
# trump_bool                             trump_perc_arrests
# apprehension_aor
# MIAMI AREA OF RESPONSIBILITY                    12.020140
# ATLANTA AREA OF RESPONSIBILITY                   7.503017
# DALLAS AREA OF RESPONSIBILITY                    8.249716
# NEW ORLEANS AREA OF RESPONSIBILITY               8.551458
# HOUSTON AREA OF RESPONSIBILITY                   7.583182
# SAN ANTONIO AREA OF RESPONSIBILITY               5.355695
# LOS ANGELES AREA OF RESPONSIBILITY               4.599088
# CHICAGO AREA OF RESPONSIBILITY                   5.996109
# BOSTON AREA OF RESPONSIBILITY                    3.564158
# WASHINGTON AREA OF RESPONSIBILITY                3.664139
# SALT LAKE CITY AREA OF RESPONSIBILITY            3.129110
# PHILADELPHIA AREA OF RESPONSIBILITY              2.894922
# PHOENIX AREA OF RESPONSIBILITY                   3.181351
# ST. PAUL AREA OF RESPONSIBILITY                  2.422042
# HARLINGEN AREA OF RESPONSIBILITY                 3.515519
# DETROIT AREA OF RESPONSIBILITY                   2.254508
# NEW YORK CITY AREA OF RESPONSIBILITY             2.185152
# DENVER AREA OF RESPONSIBILITY                    2.019420
# NEWARK AREA OF RESPONSIBILITY                    2.754409
# SAN FRANCISCO AREA OF RESPONSIBILITY             1.952766
# BALTIMORE AREA OF RESPONSIBILITY                 1.621300
# SAN DIEGO AREA OF RESPONSIBILITY                 1.173641
# EL PASO AREA OF RESPONSIBILITY                   1.668138
# SEATTLE AREA OF RESPONSIBILITY                   1.169138
# BUFFALO AREA OF RESPONSIBILITY                   0.952064
# HQ AREA OF RESPONSIBILITY                        0.019816

# %% [markdown]
# **Observations**
# * Interesting to see the differnce in AORs with the largest increase in number of arrests vs proportion of arrests - from eyeballing, it looks like mainly cities are the ones with largest prop increase (San Diego, Boston, Washington (need to check if this means DC), Denver, Buffalo (NY), Detroit, Philly
# * And then ones with the largest actual increase are ones which already had quite high numbers - Miami, Atlanta, Dallas, New Orleans, Houston, San Antonio, LA, Chicago -> NB, some of this is probably to do with population (e.g. LA and Chicago); would be good to add in populations (if mapping between county to aor is available)

# %% [markdown]
# ##### Citizenship country

# %%
eq_days_pre_post_trump.groupby('trump_bool')['citizenship_country'].nunique()
# Out:
# trump_bool
# pre_trump    168
# trump        181
# Name: citizenship_country, dtype: int64

# %%
get_summary_table(eq_days_pre_post_trump, 'citizenship_country').sort_values(by='num_increase', ascending=False)
# Out:
# trump_bool                       pre_trump    trump  fact_increase  \
# citizenship_country
# MEXICO                             19400.0  41786.0       2.153918
# GUATEMALA                           5370.0  15627.0       2.910056
# HONDURAS                            5332.0  12877.0       2.415041
# VENEZUELA                           1628.0   7983.0       4.903563
# EL SALVADOR                         2088.0   5367.0       2.570402
# COLOMBIA                            1447.0   3548.0       2.451970
# CUBA                                 737.0   2834.0       3.845319
# NICARAGUA                           1986.0   3811.0       1.918933
# ECUADOR                             1309.0   2963.0       2.263560
# BRAZIL                               564.0   1627.0       2.884752
# DOMINICAN REPUBLIC                   900.0   1834.0       2.037778
# PERU                                 502.0   1343.0       2.675299
# CHINA, PEOPLES REPUBLIC OF           231.0    941.0       4.073593
# INDIA                                242.0    805.0       3.326446
# HAITI                                196.0    620.0       3.163265
# VIETNAM                               94.0    458.0       4.872340
# JAMAICA                              285.0    583.0       2.045614
# IRAN                                  34.0    243.0       7.147059
# RUSSIA                                90.0    291.0       3.233333
# BOLIVIA                               45.0    243.0       5.400000
# ROMANIA                              198.0    386.0       1.949495
# TURKIYE                               59.0    197.0       3.338983
# SENEGAL                               33.0    166.0       5.030303
# LAOS                                  18.0    149.0       8.277778
# MAURITANIA                            45.0    153.0       3.400000
# NEPAL                                 18.0    113.0       6.277778
# EGYPT                                 41.0    131.0       3.195122
# NIGERIA                               83.0    170.0       2.048193
# CHILE                                145.0    232.0       1.600000
# SPAIN                                 51.0    123.0       2.411765
# COSTA RICA                            45.0    117.0       2.600000
# JORDAN                                56.0    128.0       2.285714
# AFGHANISTAN                           33.0    103.0       3.121212
# UZBEKISTAN                            61.0    129.0       2.114754
# GUINEA                                18.0     84.0       4.666667
# GHANA                                 31.0     92.0       2.967742
# BAHAMAS                               57.0    115.0       2.017544
# BURMA                                 18.0     74.0       4.111111
# GEORGIA                               24.0     80.0       3.333333
# UNITED KINGDOM                        35.0     90.0       2.571429
# ARGENTINA                             22.0     76.0       3.454545
# CANADA                                37.0     91.0       2.459459
# CAMEROON                              27.0     80.0       2.962963
# BHUTAN                                 6.0     58.0       9.666667
# SOMALIA                               14.0     64.0       4.571429
# BANGLADESH                            23.0     70.0       3.043478
# UKRAINE                               17.0     64.0       3.764706
# PAKISTAN                              42.0     87.0       2.071429
# ETHIOPIA                              12.0     55.0       4.583333
# LIBERIA                               19.0     58.0       3.052632
# KENYA                                 20.0     58.0       2.900000
# PHILIPPINES                           37.0     75.0       2.027027
# MICRONESIA, FEDERATED STATES OF       32.0     69.0       2.156250
# SUDAN                                 18.0     55.0       3.055556
# BELIZE                                39.0     74.0       1.897436
# MOROCCO                               13.0     46.0       3.538462
# INDONESIA                              4.0     37.0       9.250000
# ISRAEL                                11.0     44.0       4.000000
# IRAQ                                  16.0     47.0       2.937500
# CAMBODIA                              15.0     45.0       3.000000
# ANGOLA                                23.0     53.0       2.304348
# DEM REP OF THE CONGO                  23.0     52.0       2.260870
# GUYANA                                16.0     45.0       2.812500
# KYRGYZSTAN                             2.0     30.0      15.000000
# ARMENIA                               18.0     45.0       2.500000
# AZERBAIJAN                             5.0     32.0       6.400000
# ITALY                                 22.0     49.0       2.227273
# BURKINA FASO                           1.0     27.0      27.000000
# ERITREA                                9.0     34.0       3.777778
# POLAND                                18.0     43.0       2.388889
# PORTUGAL                              19.0     43.0       2.263158
# KAZAKHSTAN                            11.0     34.0       3.090909
# IRELAND                               16.0     39.0       2.437500
# TAJIKISTAN                            12.0     34.0       2.833333
# BELARUS                                6.0     27.0       4.500000
# PANAMA                                27.0     47.0       1.740741
# LEBANON                                7.0     27.0       3.857143
# ZIMBABWE                               4.0     24.0       6.000000
# MALI                                   7.0     27.0       3.857143
# SAUDI ARABIA                           4.0     23.0       5.750000
# SOUTH AFRICA                           9.0     28.0       3.111111
# CAPE VERDE                             9.0     28.0       3.111111
# SIERRA LEONE                           7.0     25.0       3.571429
# TRINIDAD AND TOBAGO                   25.0     43.0       1.720000
# SOUTH KOREA                           17.0     34.0       2.000000
# THAILAND                              10.0     27.0       2.700000
# ALBANIA                               12.0     28.0       2.333333
# SOUTH SUDAN                            2.0     17.0       8.500000
# HUNGARY                                8.0     23.0       2.875000
# CONGO                                 11.0     25.0       2.272727
# BELGIUM                                2.0     15.0       7.500000
# YEMEN                                  5.0     18.0       3.600000
# SYRIA                                 17.0     30.0       1.764706
# EQUATORIAL GUINEA                      2.0     14.0       7.000000
# URUGUAY                                9.0     21.0       2.333333
# TOGO                                   5.0     17.0       3.400000
# NIGER                                  4.0     16.0       4.000000
# NETHERLANDS                            2.0     14.0       7.000000
# FRANCE                                15.0     26.0       1.733333
# SRI LANKA                              6.0     17.0       2.833333
# TAIWAN                                11.0     22.0       2.000000
# IVORY COAST                            8.0     19.0       2.375000
# GERMANY                               11.0     21.0       1.909091
# AUSTRALIA                              4.0     14.0       3.500000
# MOLDOVA                                5.0     15.0       3.000000
# ST. LUCIA                              6.0     14.0       2.333333
# BENIN                                  3.0     11.0       3.666667
# GAMBIA                                 7.0     15.0       2.142857
# HONG KONG                              1.0      9.0       9.000000
# BULGARIA                               1.0      9.0       9.000000
# TANZANIA                               5.0     12.0       2.400000
# USSR                                   2.0      8.0       4.000000
# UGANDA                                 2.0      8.0       4.000000
# BARBADOS                               4.0     10.0       2.500000
# TUNISIA                                5.0     10.0       2.000000
# ALGERIA                                7.0     12.0       1.714286
# GRENADA                                1.0      6.0       6.000000
# DOMINICA                               4.0      9.0       2.250000
# MONTENEGRO                             1.0      6.0       6.000000
# SURINAME                               2.0      6.0       3.000000
# SLOVAKIA                               2.0      6.0       3.000000
# PARAGUAY                               4.0      8.0       2.000000
# MONGOLIA                               1.0      5.0       5.000000
# PALAU                                  1.0      5.0       5.000000
# KOSOVO                                 2.0      5.0       2.500000
# ST. KITTS-NEVIS                        4.0      7.0       1.750000
# YUGOSLAVIA                             1.0      4.0       4.000000
# ANTIGUA-BARBUDA                        1.0      4.0       4.000000
# GREECE                                 5.0      8.0       1.600000
# SAMOA                                  2.0      5.0       2.500000
# LATVIA                                 3.0      6.0       2.000000
# BURUNDI                                5.0      8.0       1.600000
# RWANDA                                 8.0     11.0       1.375000
# MALAWI                                 1.0      4.0       4.000000
# BOSNIA-HERZEGOVINA                    13.0     16.0       1.230769
# LIBYA                                  2.0      4.0       2.000000
# SLOVENIA                               1.0      3.0       3.000000
# TURKS AND CAICOS ISLANDS               2.0      4.0       2.000000
# TONGA                                  5.0      7.0       1.400000
# BRITISH VIRGIN ISLANDS                 2.0      4.0       2.000000
# KOREA                                  3.0      5.0       1.666667
# KUWAIT                                 1.0      3.0       3.000000
# JAPAN                                  2.0      3.0       1.500000
# LITHUANIA                              2.0      3.0       1.500000
# ZAMBIA                                 5.0      6.0       1.200000
# MAURITIUS                              1.0      2.0       2.000000
# GABON                                  2.0      3.0       1.500000
# CZECH REPUBLIC                         5.0      6.0       1.200000
# ST. VINCENT-GRENADINES                 1.0      2.0       2.000000
# FINLAND                                1.0      2.0       2.000000
# MALTA                                  1.0      1.0       1.000000
# MONTSERRAT                             1.0      1.0       1.000000
# MOZAMBIQUE                             1.0      1.0       1.000000
# CROATIA                                2.0      2.0       1.000000
# BAHRAIN                                1.0      1.0       1.000000
# NORTH MACEDONIA                        1.0      1.0       1.000000
# PAPUA NEW GUINEA                       1.0      1.0       1.000000
# FIJI                                   3.0      3.0       1.000000
# MARSHALL ISLANDS                      36.0     34.0       0.944444
# SWEDEN                                 5.0      3.0       0.600000
# MALAYSIA                               3.0      1.0       0.333333
# CHAD                                   8.0      4.0       0.500000
# ANDORRA                                NaN      1.0            NaN
# ANGUILLA                               NaN      1.0            NaN
# BOTSWANA                               NaN      2.0            NaN
# BRUNEI                                 1.0      NaN            NaN
# CENTRAL AFRICAN REPUBLIC               NaN      3.0            NaN
# CYPRUS                                 1.0      NaN            NaN
# DENMARK                                NaN      2.0            NaN
# DJIBOUTI                               NaN      1.0            NaN
# EAST TIMOR                             NaN      1.0            NaN
# ESTONIA                                NaN      1.0            NaN
# FRENCH POLYNESIA                       1.0      NaN            NaN
# GUADELOUPE                             NaN      3.0            NaN
# GUINEA-BISSAU                          NaN      5.0            NaN
# NAMIBIA                                NaN      1.0            NaN
# NEW ZEALAND                            NaN     14.0            NaN
# NORWAY                                 1.0      NaN            NaN
# OMAN                                   NaN      2.0            NaN
# SAO TOME AND PRINCIPE                  NaN      1.0            NaN
# SERBIA                                 NaN      4.0            NaN
# SERBIA AND MONTENEGRO                  NaN      2.0            NaN
# SINT EUSTATIUS                         NaN      1.0            NaN
# SINT MAARTEN(DUTCH)                    2.0      NaN            NaN
# SWITZERLAND                            1.0      NaN            NaN
# TURKMENISTAN                           NaN      3.0            NaN
# UNITED ARAB EMIRATES                   NaN      1.0            NaN
#
# trump_bool                       num_increase  pre_trump_perc_arrests  \
# citizenship_country
# MEXICO                                22386.0               43.450994
# GUATEMALA                             10257.0               12.027414
# HONDURAS                               7545.0               11.942304
# VENEZUELA                              6355.0                3.646300
# EL SALVADOR                            3279.0                4.676581
# COLOMBIA                               2101.0                3.240907
# CUBA                                   2097.0                1.650690
# NICARAGUA                              1825.0                4.448128
# ECUADOR                                1654.0                2.931822
# BRAZIL                                 1063.0                1.263214
# DOMINICAN REPUBLIC                      934.0                2.015768
# PERU                                    841.0                1.124350
# CHINA, PEOPLES REPUBLIC OF              710.0                0.517380
# INDIA                                   563.0                0.542018
# HAITI                                   424.0                0.438989
# VIETNAM                                 364.0                0.210536
# JAMAICA                                 298.0                0.638326
# IRAN                                    209.0                0.076151
# RUSSIA                                  201.0                0.201577
# BOLIVIA                                 198.0                0.100788
# ROMANIA                                 188.0                0.443469
# TURKIYE                                 138.0                0.132145
# SENEGAL                                 133.0                0.073911
# LAOS                                    131.0                0.040315
# MAURITANIA                              108.0                0.100788
# NEPAL                                    95.0                0.040315
# EGYPT                                    90.0                0.091829
# NIGERIA                                  87.0                0.185899
# CHILE                                    87.0                0.324763
# SPAIN                                    72.0                0.114227
# COSTA RICA                               72.0                0.100788
# JORDAN                                   72.0                0.125426
# AFGHANISTAN                              70.0                0.073911
# UZBEKISTAN                               68.0                0.136624
# GUINEA                                   66.0                0.040315
# GHANA                                    61.0                0.069432
# BAHAMAS                                  58.0                0.127665
# BURMA                                    56.0                0.040315
# GEORGIA                                  56.0                0.053754
# UNITED KINGDOM                           55.0                0.078391
# ARGENTINA                                54.0                0.049274
# CANADA                                   54.0                0.082870
# CAMEROON                                 53.0                0.060473
# BHUTAN                                   52.0                0.013438
# SOMALIA                                  50.0                0.031356
# BANGLADESH                               47.0                0.051514
# UKRAINE                                  47.0                0.038076
# PAKISTAN                                 45.0                0.094069
# ETHIOPIA                                 43.0                0.026877
# LIBERIA                                  39.0                0.042555
# KENYA                                    38.0                0.044795
# PHILIPPINES                              38.0                0.082870
# MICRONESIA, FEDERATED STATES OF          37.0                0.071672
# SUDAN                                    37.0                0.040315
# BELIZE                                   35.0                0.087350
# MOROCCO                                  33.0                0.029117
# INDONESIA                                33.0                0.008959
# ISRAEL                                   33.0                0.024637
# IRAQ                                     31.0                0.035836
# CAMBODIA                                 30.0                0.033596
# ANGOLA                                   30.0                0.051514
# DEM REP OF THE CONGO                     29.0                0.051514
# GUYANA                                   29.0                0.035836
# KYRGYZSTAN                               28.0                0.004479
# ARMENIA                                  27.0                0.040315
# AZERBAIJAN                               27.0                0.011199
# ITALY                                    27.0                0.049274
# BURKINA FASO                             26.0                0.002240
# ERITREA                                  25.0                0.020158
# POLAND                                   25.0                0.040315
# PORTUGAL                                 24.0                0.042555
# KAZAKHSTAN                               23.0                0.024637
# IRELAND                                  23.0                0.035836
# TAJIKISTAN                               22.0                0.026877
# BELARUS                                  21.0                0.013438
# PANAMA                                   20.0                0.060473
# LEBANON                                  20.0                0.015678
# ZIMBABWE                                 20.0                0.008959
# MALI                                     20.0                0.015678
# SAUDI ARABIA                             19.0                0.008959
# SOUTH AFRICA                             19.0                0.020158
# CAPE VERDE                               19.0                0.020158
# SIERRA LEONE                             18.0                0.015678
# TRINIDAD AND TOBAGO                      18.0                0.055994
# SOUTH KOREA                              17.0                0.038076
# THAILAND                                 17.0                0.022397
# ALBANIA                                  16.0                0.026877
# SOUTH SUDAN                              15.0                0.004479
# HUNGARY                                  15.0                0.017918
# CONGO                                    14.0                0.024637
# BELGIUM                                  13.0                0.004479
# YEMEN                                    13.0                0.011199
# SYRIA                                    13.0                0.038076
# EQUATORIAL GUINEA                        12.0                0.004479
# URUGUAY                                  12.0                0.020158
# TOGO                                     12.0                0.011199
# NIGER                                    12.0                0.008959
# NETHERLANDS                              12.0                0.004479
# FRANCE                                   11.0                0.033596
# SRI LANKA                                11.0                0.013438
# TAIWAN                                   11.0                0.024637
# IVORY COAST                              11.0                0.017918
# GERMANY                                  10.0                0.024637
# AUSTRALIA                                10.0                0.008959
# MOLDOVA                                  10.0                0.011199
# ST. LUCIA                                 8.0                0.013438
# BENIN                                     8.0                0.006719
# GAMBIA                                    8.0                0.015678
# HONG KONG                                 8.0                0.002240
# BULGARIA                                  8.0                0.002240
# TANZANIA                                  7.0                0.011199
# USSR                                      6.0                0.004479
# UGANDA                                    6.0                0.004479
# BARBADOS                                  6.0                0.008959
# TUNISIA                                   5.0                0.011199
# ALGERIA                                   5.0                0.015678
# GRENADA                                   5.0                0.002240
# DOMINICA                                  5.0                0.008959
# MONTENEGRO                                5.0                0.002240
# SURINAME                                  4.0                0.004479
# SLOVAKIA                                  4.0                0.004479
# PARAGUAY                                  4.0                0.008959
# MONGOLIA                                  4.0                0.002240
# PALAU                                     4.0                0.002240
# KOSOVO                                    3.0                0.004479
# ST. KITTS-NEVIS                           3.0                0.008959
# YUGOSLAVIA                                3.0                0.002240
# ANTIGUA-BARBUDA                           3.0                0.002240
# GREECE                                    3.0                0.011199
# SAMOA                                     3.0                0.004479
# LATVIA                                    3.0                0.006719
# BURUNDI                                   3.0                0.011199
# RWANDA                                    3.0                0.017918
# MALAWI                                    3.0                0.002240
# BOSNIA-HERZEGOVINA                        3.0                0.029117
# LIBYA                                     2.0                0.004479
# SLOVENIA                                  2.0                0.002240
# TURKS AND CAICOS ISLANDS                  2.0                0.004479
# TONGA                                     2.0                0.011199
# BRITISH VIRGIN ISLANDS                    2.0                0.004479
# KOREA                                     2.0                0.006719
# KUWAIT                                    2.0                0.002240
# JAPAN                                     1.0                0.004479
# LITHUANIA                                 1.0                0.004479
# ZAMBIA                                    1.0                0.011199
# MAURITIUS                                 1.0                0.002240
# GABON                                     1.0                0.004479
# CZECH REPUBLIC                            1.0                0.011199
# ST. VINCENT-GRENADINES                    1.0                0.002240
# FINLAND                                   1.0                0.002240
# MALTA                                     0.0                0.002240
# MONTSERRAT                                0.0                0.002240
# MOZAMBIQUE                                0.0                0.002240
# CROATIA                                   0.0                0.004479
# BAHRAIN                                   0.0                0.002240
# NORTH MACEDONIA                           0.0                0.002240
# PAPUA NEW GUINEA                          0.0                0.002240
# FIJI                                      0.0                0.006719
# MARSHALL ISLANDS                         -2.0                0.080631
# SWEDEN                                   -2.0                0.011199
# MALAYSIA                                 -2.0                0.006719
# CHAD                                     -4.0                0.017918
# ANDORRA                                   NaN                     NaN
# ANGUILLA                                  NaN                     NaN
# BOTSWANA                                  NaN                     NaN
# BRUNEI                                    NaN                0.002240
# CENTRAL AFRICAN REPUBLIC                  NaN                     NaN
# CYPRUS                                    NaN                0.002240
# DENMARK                                   NaN                     NaN
# DJIBOUTI                                  NaN                     NaN
# EAST TIMOR                                NaN                     NaN
# ESTONIA                                   NaN                     NaN
# FRENCH POLYNESIA                          NaN                0.002240
# GUADELOUPE                                NaN                     NaN
# GUINEA-BISSAU                             NaN                     NaN
# NAMIBIA                                   NaN                     NaN
# NEW ZEALAND                               NaN                     NaN
# NORWAY                                    NaN                0.002240
# OMAN                                      NaN                     NaN
# SAO TOME AND PRINCIPE                     NaN                     NaN
# SERBIA                                    NaN                     NaN
# SERBIA AND MONTENEGRO                     NaN                     NaN
# SINT EUSTATIUS                            NaN                     NaN
# SINT MAARTEN(DUTCH)                       NaN                0.004479
# SWITZERLAND                               NaN                0.002240
# TURKMENISTAN                              NaN                     NaN
# UNITED ARAB EMIRATES                      NaN                     NaN
#
# trump_bool                       trump_perc_arrests
# citizenship_country
# MEXICO                                    37.453727
# GUATEMALA                                 14.006830
# HONDURAS                                  11.541943
# VENEZUELA                                  7.155342
# EL SALVADOR                                4.810562
# COLOMBIA                                   3.180152
# CUBA                                       2.540178
# NICARAGUA                                  3.415885
# ECUADOR                                    2.655803
# BRAZIL                                     1.458317
# DOMINICAN REPUBLIC                         1.643855
# PERU                                       1.203761
# CHINA, PEOPLES REPUBLIC OF                 0.843439
# INDIA                                      0.721540
# HAITI                                      0.555720
# VIETNAM                                    0.410516
# JAMAICA                                    0.522556
# IRAN                                       0.217806
# RUSSIA                                     0.260830
# BOLIVIA                                    0.217806
# ROMANIA                                    0.345980
# TURKIYE                                    0.176576
# SENEGAL                                    0.148790
# LAOS                                       0.133552
# MAURITANIA                                 0.137137
# NEPAL                                      0.101284
# EGYPT                                      0.117418
# NIGERIA                                    0.152375
# CHILE                                      0.207947
# SPAIN                                      0.110248
# COSTA RICA                                 0.104870
# JORDAN                                     0.114729
# AFGHANISTAN                                0.092321
# UZBEKISTAN                                 0.115626
# GUINEA                                     0.075291
# GHANA                                      0.082462
# BAHAMAS                                    0.103077
# BURMA                                      0.066328
# GEORGIA                                    0.071706
# UNITED KINGDOM                             0.080669
# ARGENTINA                                  0.068121
# CANADA                                     0.081565
# CAMEROON                                   0.071706
# BHUTAN                                     0.051987
# SOMALIA                                    0.057365
# BANGLADESH                                 0.062743
# UKRAINE                                    0.057365
# PAKISTAN                                   0.077980
# ETHIOPIA                                   0.049298
# LIBERIA                                    0.051987
# KENYA                                      0.051987
# PHILIPPINES                                0.067224
# MICRONESIA, FEDERATED STATES OF            0.061846
# SUDAN                                      0.049298
# BELIZE                                     0.066328
# MOROCCO                                    0.041231
# INDONESIA                                  0.033164
# ISRAEL                                     0.039438
# IRAQ                                       0.042127
# CAMBODIA                                   0.040335
# ANGOLA                                     0.047505
# DEM REP OF THE CONGO                       0.046609
# GUYANA                                     0.040335
# KYRGYZSTAN                                 0.026890
# ARMENIA                                    0.040335
# AZERBAIJAN                                 0.028682
# ITALY                                      0.043920
# BURKINA FASO                               0.024201
# ERITREA                                    0.030475
# POLAND                                     0.038542
# PORTUGAL                                   0.038542
# KAZAKHSTAN                                 0.030475
# IRELAND                                    0.034957
# TAJIKISTAN                                 0.030475
# BELARUS                                    0.024201
# PANAMA                                     0.042127
# LEBANON                                    0.024201
# ZIMBABWE                                   0.021512
# MALI                                       0.024201
# SAUDI ARABIA                               0.020615
# SOUTH AFRICA                               0.025097
# CAPE VERDE                                 0.025097
# SIERRA LEONE                               0.022408
# TRINIDAD AND TOBAGO                        0.038542
# SOUTH KOREA                                0.030475
# THAILAND                                   0.024201
# ALBANIA                                    0.025097
# SOUTH SUDAN                                0.015237
# HUNGARY                                    0.020615
# CONGO                                      0.022408
# BELGIUM                                    0.013445
# YEMEN                                      0.016134
# SYRIA                                      0.026890
# EQUATORIAL GUINEA                          0.012549
# URUGUAY                                    0.018823
# TOGO                                       0.015237
# NIGER                                      0.014341
# NETHERLANDS                                0.012549
# FRANCE                                     0.023304
# SRI LANKA                                  0.015237
# TAIWAN                                     0.019719
# IVORY COAST                                0.017030
# GERMANY                                    0.018823
# AUSTRALIA                                  0.012549
# MOLDOVA                                    0.013445
# ST. LUCIA                                  0.012549
# BENIN                                      0.009860
# GAMBIA                                     0.013445
# HONG KONG                                  0.008067
# BULGARIA                                   0.008067
# TANZANIA                                   0.010756
# USSR                                       0.007171
# UGANDA                                     0.007171
# BARBADOS                                   0.008963
# TUNISIA                                    0.008963
# ALGERIA                                    0.010756
# GRENADA                                    0.005378
# DOMINICA                                   0.008067
# MONTENEGRO                                 0.005378
# SURINAME                                   0.005378
# SLOVAKIA                                   0.005378
# PARAGUAY                                   0.007171
# MONGOLIA                                   0.004482
# PALAU                                      0.004482
# KOSOVO                                     0.004482
# ST. KITTS-NEVIS                            0.006274
# YUGOSLAVIA                                 0.003585
# ANTIGUA-BARBUDA                            0.003585
# GREECE                                     0.007171
# SAMOA                                      0.004482
# LATVIA                                     0.005378
# BURUNDI                                    0.007171
# RWANDA                                     0.009860
# MALAWI                                     0.003585
# BOSNIA-HERZEGOVINA                         0.014341
# LIBYA                                      0.003585
# SLOVENIA                                   0.002689
# TURKS AND CAICOS ISLANDS                   0.003585
# TONGA                                      0.006274
# BRITISH VIRGIN ISLANDS                     0.003585
# KOREA                                      0.004482
# KUWAIT                                     0.002689
# JAPAN                                      0.002689
# LITHUANIA                                  0.002689
# ZAMBIA                                     0.005378
# MAURITIUS                                  0.001793
# GABON                                      0.002689
# CZECH REPUBLIC                             0.005378
# ST. VINCENT-GRENADINES                     0.001793
# FINLAND                                    0.001793
# MALTA                                      0.000896
# MONTSERRAT                                 0.000896
# MOZAMBIQUE                                 0.000896
# CROATIA                                    0.001793
# BAHRAIN                                    0.000896
# NORTH MACEDONIA                            0.000896
# PAPUA NEW GUINEA                           0.000896
# FIJI                                       0.002689
# MARSHALL ISLANDS                           0.030475
# SWEDEN                                     0.002689
# MALAYSIA                                   0.000896
# CHAD                                       0.003585
# ANDORRA                                    0.000896
# ANGUILLA                                   0.000896
# BOTSWANA                                   0.001793
# BRUNEI                                          NaN
# CENTRAL AFRICAN REPUBLIC                   0.002689
# CYPRUS                                          NaN
# DENMARK                                    0.001793
# DJIBOUTI                                   0.000896
# EAST TIMOR                                 0.000896
# ESTONIA                                    0.000896
# FRENCH POLYNESIA                                NaN
# GUADELOUPE                                 0.002689
# GUINEA-BISSAU                              0.004482
# NAMIBIA                                    0.000896
# NEW ZEALAND                                0.012549
# NORWAY                                          NaN
# OMAN                                       0.001793
# SAO TOME AND PRINCIPE                      0.000896
# SERBIA                                     0.003585
# SERBIA AND MONTENEGRO                      0.001793
# SINT EUSTATIUS                             0.000896
# SINT MAARTEN(DUTCH)                             NaN
# SWITZERLAND                                     NaN
# TURKMENISTAN                               0.002689
# UNITED ARAB EMIRATES                       0.000896

# %%
get_summary_table(eq_days_pre_post_trump, 'citizenship_continent')
# Out:
# trump_bool                 pre_trump  trump  fact_increase  num_increase  \
# citizenship_continent
# AFRICA                           559   1738       3.109123          1179
# ASIA                            1181   4294       3.635902          3113
# EUROPE                           578   1396       2.415225           818
# NORTH AND CENTRAL AMERICA      36597  86135       2.353608         49538
# OCEANIA                           85    152       1.788235            67
# SOUTH AMERICA                   5648  17852       3.160765         12204
#
# trump_bool                 pre_trump_perc_arrests  trump_perc_arrests
# citizenship_continent
# AFRICA                                   1.252016            1.557808
# ASIA                                     2.645135            3.848808
# EUROPE                                   1.294571            1.251266
# NORTH AND CENTRAL AMERICA               81.967837           77.204729
# OCEANIA                                  0.190378            0.136241
# SOUTH AMERICA                           12.650063           16.001147

# %%
aor_summary_country = eq_days_pre_post_trump.groupby('apprehension_aor').apply(get_summary_table)

# %%
aor_summary_country.sort_values(by='num_increase', ascending=False).head(20)
# Out:
# trump_bool                                                 pre_trump   trump  \
# apprehension_aor                      citizenship_country
# ATLANTA AREA OF RESPONSIBILITY        MEXICO                  1210.0  3356.0
# MIAMI AREA OF RESPONSIBILITY          GUATEMALA                836.0  2875.0
# DALLAS AREA OF RESPONSIBILITY         MEXICO                  2545.0  4550.0
# HARLINGEN AREA OF RESPONSIBILITY      MEXICO                  1406.0  3196.0
# MIAMI AREA OF RESPONSIBILITY          MEXICO                  1025.0  2753.0
# LOS ANGELES AREA OF RESPONSIBILITY    MEXICO                   928.0  2573.0
# NEW ORLEANS AREA OF RESPONSIBILITY    MEXICO                  1944.0  3542.0
# HOUSTON AREA OF RESPONSIBILITY        MEXICO                  2148.0  3636.0
# CHICAGO AREA OF RESPONSIBILITY        MEXICO                  1437.0  2709.0
# PHOENIX AREA OF RESPONSIBILITY        MEXICO                  1285.0  2454.0
# SALT LAKE CITY AREA OF RESPONSIBILITY MEXICO                   774.0  1909.0
# MIAMI AREA OF RESPONSIBILITY          HONDURAS                 494.0  1588.0
# NEW ORLEANS AREA OF RESPONSIBILITY    GUATEMALA               1000.0  2057.0
# ATLANTA AREA OF RESPONSIBILITY        GUATEMALA                396.0  1405.0
# MIAMI AREA OF RESPONSIBILITY          CUBA                     243.0  1244.0
# SAN ANTONIO AREA OF RESPONSIBILITY    MEXICO                  1193.0  2139.0
# HOUSTON AREA OF RESPONSIBILITY        HONDURAS                 875.0  1797.0
# DALLAS AREA OF RESPONSIBILITY         VENEZUELA                181.0  1079.0
# NEW ORLEANS AREA OF RESPONSIBILITY    HONDURAS                 856.0  1719.0
# ATLANTA AREA OF RESPONSIBILITY        HONDURAS                 346.0  1129.0
#
# trump_bool                                                 fact_increase  \
# apprehension_aor                      citizenship_country
# ATLANTA AREA OF RESPONSIBILITY        MEXICO                    2.773554
# MIAMI AREA OF RESPONSIBILITY          GUATEMALA                 3.438995
# DALLAS AREA OF RESPONSIBILITY         MEXICO                    1.787819
# HARLINGEN AREA OF RESPONSIBILITY      MEXICO                    2.273115
# MIAMI AREA OF RESPONSIBILITY          MEXICO                    2.685854
# LOS ANGELES AREA OF RESPONSIBILITY    MEXICO                    2.772629
# NEW ORLEANS AREA OF RESPONSIBILITY    MEXICO                    1.822016
# HOUSTON AREA OF RESPONSIBILITY        MEXICO                    1.692737
# CHICAGO AREA OF RESPONSIBILITY        MEXICO                    1.885177
# PHOENIX AREA OF RESPONSIBILITY        MEXICO                    1.909728
# SALT LAKE CITY AREA OF RESPONSIBILITY MEXICO                    2.466408
# MIAMI AREA OF RESPONSIBILITY          HONDURAS                  3.214575
# NEW ORLEANS AREA OF RESPONSIBILITY    GUATEMALA                 2.057000
# ATLANTA AREA OF RESPONSIBILITY        GUATEMALA                 3.547980
# MIAMI AREA OF RESPONSIBILITY          CUBA                      5.119342
# SAN ANTONIO AREA OF RESPONSIBILITY    MEXICO                    1.792959
# HOUSTON AREA OF RESPONSIBILITY        HONDURAS                  2.053714
# DALLAS AREA OF RESPONSIBILITY         VENEZUELA                 5.961326
# NEW ORLEANS AREA OF RESPONSIBILITY    HONDURAS                  2.008178
# ATLANTA AREA OF RESPONSIBILITY        HONDURAS                  3.263006
#
# trump_bool                                                 num_increase  \
# apprehension_aor                      citizenship_country
# ATLANTA AREA OF RESPONSIBILITY        MEXICO                     2146.0
# MIAMI AREA OF RESPONSIBILITY          GUATEMALA                  2039.0
# DALLAS AREA OF RESPONSIBILITY         MEXICO                     2005.0
# HARLINGEN AREA OF RESPONSIBILITY      MEXICO                     1790.0
# MIAMI AREA OF RESPONSIBILITY          MEXICO                     1728.0
# LOS ANGELES AREA OF RESPONSIBILITY    MEXICO                     1645.0
# NEW ORLEANS AREA OF RESPONSIBILITY    MEXICO                     1598.0
# HOUSTON AREA OF RESPONSIBILITY        MEXICO                     1488.0
# CHICAGO AREA OF RESPONSIBILITY        MEXICO                     1272.0
# PHOENIX AREA OF RESPONSIBILITY        MEXICO                     1169.0
# SALT LAKE CITY AREA OF RESPONSIBILITY MEXICO                     1135.0
# MIAMI AREA OF RESPONSIBILITY          HONDURAS                   1094.0
# NEW ORLEANS AREA OF RESPONSIBILITY    GUATEMALA                  1057.0
# ATLANTA AREA OF RESPONSIBILITY        GUATEMALA                  1009.0
# MIAMI AREA OF RESPONSIBILITY          CUBA                       1001.0
# SAN ANTONIO AREA OF RESPONSIBILITY    MEXICO                      946.0
# HOUSTON AREA OF RESPONSIBILITY        HONDURAS                    922.0
# DALLAS AREA OF RESPONSIBILITY         VENEZUELA                   898.0
# NEW ORLEANS AREA OF RESPONSIBILITY    HONDURAS                    863.0
# ATLANTA AREA OF RESPONSIBILITY        HONDURAS                    783.0
#
# trump_bool                                                 pre_trump_perc_arrests  \
# apprehension_aor                      citizenship_country
# ATLANTA AREA OF RESPONSIBILITY        MEXICO                            44.881306
# MIAMI AREA OF RESPONSIBILITY          GUATEMALA                         19.482638
# DALLAS AREA OF RESPONSIBILITY         MEXICO                            59.560028
# HARLINGEN AREA OF RESPONSIBILITY      MEXICO                            65.243619
# MIAMI AREA OF RESPONSIBILITY          MEXICO                            23.887206
# LOS ANGELES AREA OF RESPONSIBILITY    MEXICO                            54.428152
# NEW ORLEANS AREA OF RESPONSIBILITY    MEXICO                            41.142857
# HOUSTON AREA OF RESPONSIBILITY        MEXICO                            48.542373
# CHICAGO AREA OF RESPONSIBILITY        MEXICO                            42.451994
# PHOENIX AREA OF RESPONSIBILITY        MEXICO                            76.261128
# SALT LAKE CITY AREA OF RESPONSIBILITY MEXICO                            61.331220
# MIAMI AREA OF RESPONSIBILITY          HONDURAS                          11.512468
# NEW ORLEANS AREA OF RESPONSIBILITY    GUATEMALA                         21.164021
# ATLANTA AREA OF RESPONSIBILITY        GUATEMALA                         14.688427
# MIAMI AREA OF RESPONSIBILITY          CUBA                               5.663016
# SAN ANTONIO AREA OF RESPONSIBILITY    MEXICO                            48.124244
# HOUSTON AREA OF RESPONSIBILITY        HONDURAS                          19.774011
# DALLAS AREA OF RESPONSIBILITY         VENEZUELA                          4.235900
# NEW ORLEANS AREA OF RESPONSIBILITY    HONDURAS                          18.116402
# ATLANTA AREA OF RESPONSIBILITY        HONDURAS                          12.833828
#
# trump_bool                                                 trump_perc_arrests
# apprehension_aor                      citizenship_country
# ATLANTA AREA OF RESPONSIBILITY        MEXICO                        40.288115
# MIAMI AREA OF RESPONSIBILITY          GUATEMALA                     21.543649
# DALLAS AREA OF RESPONSIBILITY         MEXICO                        49.677912
# HARLINGEN AREA OF RESPONSIBILITY      MEXICO                        81.885729
# MIAMI AREA OF RESPONSIBILITY          MEXICO                        20.629449
# LOS ANGELES AREA OF RESPONSIBILITY    MEXICO                        50.391696
# NEW ORLEANS AREA OF RESPONSIBILITY    MEXICO                        37.307773
# HOUSTON AREA OF RESPONSIBILITY        MEXICO                        43.188027
# CHICAGO AREA OF RESPONSIBILITY        MEXICO                        40.694006
# PHOENIX AREA OF RESPONSIBILITY        MEXICO                        69.479049
# SALT LAKE CITY AREA OF RESPONSIBILITY MEXICO                        54.951065
# MIAMI AREA OF RESPONSIBILITY          HONDURAS                      11.899588
# NEW ORLEANS AREA OF RESPONSIBILITY    GUATEMALA                     21.666316
# ATLANTA AREA OF RESPONSIBILITY        GUATEMALA                     16.866747
# MIAMI AREA OF RESPONSIBILITY          CUBA                           9.321843
# SAN ANTONIO AREA OF RESPONSIBILITY    MEXICO                        35.973764
# HOUSTON AREA OF RESPONSIBILITY        HONDURAS                      21.344578
# DALLAS AREA OF RESPONSIBILITY         VENEZUELA                     11.780762
# NEW ORLEANS AREA OF RESPONSIBILITY    HONDURAS                      18.106172
# ATLANTA AREA OF RESPONSIBILITY        HONDURAS                      13.553421

# %%
aor_summary_country.sort_values(by='fact_increase', ascending=False).head(20)
# Out:
# trump_bool                                                        pre_trump  \
# apprehension_aor                      citizenship_country
# WASHINGTON AREA OF RESPONSIBILITY     INDIA                             1.0
# NEW YORK CITY AREA OF RESPONSIBILITY  HAITI                             1.0
# WASHINGTON AREA OF RESPONSIBILITY     AFGHANISTAN                       1.0
#                                       EGYPT                             1.0
#                                       CUBA                              2.0
# SEATTLE AREA OF RESPONSIBILITY        PERU                              1.0
# LOS ANGELES AREA OF RESPONSIBILITY    IRAN                              3.0
# WASHINGTON AREA OF RESPONSIBILITY     CHINA, PEOPLES REPUBLIC OF        1.0
# DETROIT AREA OF RESPONSIBILITY        SENEGAL                           1.0
# SAN FRANCISCO AREA OF RESPONSIBILITY  VENEZUELA                         3.0
# PHOENIX AREA OF RESPONSIBILITY        VIETNAM                           1.0
# SALT LAKE CITY AREA OF RESPONSIBILITY CUBA                              3.0
# NEW YORK CITY AREA OF RESPONSIBILITY  MAURITANIA                        1.0
# LOS ANGELES AREA OF RESPONSIBILITY    CHINA, PEOPLES REPUBLIC OF       10.0
# WASHINGTON AREA OF RESPONSIBILITY     CAMEROON                          2.0
#                                       BRAZIL                            1.0
# SAN FRANCISCO AREA OF RESPONSIBILITY  INDIA                             9.0
# CHICAGO AREA OF RESPONSIBILITY        VIETNAM                           1.0
# WASHINGTON AREA OF RESPONSIBILITY     TURKIYE                           1.0
# PHILADELPHIA AREA OF RESPONSIBILITY   MAURITANIA                        1.0
#
# trump_bool                                                        trump  \
# apprehension_aor                      citizenship_country
# WASHINGTON AREA OF RESPONSIBILITY     INDIA                        36.0
# NEW YORK CITY AREA OF RESPONSIBILITY  HAITI                        36.0
# WASHINGTON AREA OF RESPONSIBILITY     AFGHANISTAN                  31.0
#                                       EGYPT                        30.0
#                                       CUBA                         53.0
# SEATTLE AREA OF RESPONSIBILITY        PERU                         24.0
# LOS ANGELES AREA OF RESPONSIBILITY    IRAN                         68.0
# WASHINGTON AREA OF RESPONSIBILITY     CHINA, PEOPLES REPUBLIC OF   21.0
# DETROIT AREA OF RESPONSIBILITY        SENEGAL                      21.0
# SAN FRANCISCO AREA OF RESPONSIBILITY  VENEZUELA                    62.0
# PHOENIX AREA OF RESPONSIBILITY        VIETNAM                      20.0
# SALT LAKE CITY AREA OF RESPONSIBILITY CUBA                         57.0
# NEW YORK CITY AREA OF RESPONSIBILITY  MAURITANIA                   18.0
# LOS ANGELES AREA OF RESPONSIBILITY    CHINA, PEOPLES REPUBLIC OF  178.0
# WASHINGTON AREA OF RESPONSIBILITY     CAMEROON                     34.0
#                                       BRAZIL                       16.0
# SAN FRANCISCO AREA OF RESPONSIBILITY  INDIA                       144.0
# CHICAGO AREA OF RESPONSIBILITY        VIETNAM                      16.0
# WASHINGTON AREA OF RESPONSIBILITY     TURKIYE                      15.0
# PHILADELPHIA AREA OF RESPONSIBILITY   MAURITANIA                   15.0
#
# trump_bool                                                        fact_increase  \
# apprehension_aor                      citizenship_country
# WASHINGTON AREA OF RESPONSIBILITY     INDIA                           36.000000
# NEW YORK CITY AREA OF RESPONSIBILITY  HAITI                           36.000000
# WASHINGTON AREA OF RESPONSIBILITY     AFGHANISTAN                     31.000000
#                                       EGYPT                           30.000000
#                                       CUBA                            26.500000
# SEATTLE AREA OF RESPONSIBILITY        PERU                            24.000000
# LOS ANGELES AREA OF RESPONSIBILITY    IRAN                            22.666667
# WASHINGTON AREA OF RESPONSIBILITY     CHINA, PEOPLES REPUBLIC OF      21.000000
# DETROIT AREA OF RESPONSIBILITY        SENEGAL                         21.000000
# SAN FRANCISCO AREA OF RESPONSIBILITY  VENEZUELA                       20.666667
# PHOENIX AREA OF RESPONSIBILITY        VIETNAM                         20.000000
# SALT LAKE CITY AREA OF RESPONSIBILITY CUBA                            19.000000
# NEW YORK CITY AREA OF RESPONSIBILITY  MAURITANIA                      18.000000
# LOS ANGELES AREA OF RESPONSIBILITY    CHINA, PEOPLES REPUBLIC OF      17.800000
# WASHINGTON AREA OF RESPONSIBILITY     CAMEROON                        17.000000
#                                       BRAZIL                          16.000000
# SAN FRANCISCO AREA OF RESPONSIBILITY  INDIA                           16.000000
# CHICAGO AREA OF RESPONSIBILITY        VIETNAM                         16.000000
# WASHINGTON AREA OF RESPONSIBILITY     TURKIYE                         15.000000
# PHILADELPHIA AREA OF RESPONSIBILITY   MAURITANIA                      15.000000
#
# trump_bool                                                        num_increase  \
# apprehension_aor                      citizenship_country
# WASHINGTON AREA OF RESPONSIBILITY     INDIA                               35.0
# NEW YORK CITY AREA OF RESPONSIBILITY  HAITI                               35.0
# WASHINGTON AREA OF RESPONSIBILITY     AFGHANISTAN                         30.0
#                                       EGYPT                               29.0
#                                       CUBA                                51.0
# SEATTLE AREA OF RESPONSIBILITY        PERU                                23.0
# LOS ANGELES AREA OF RESPONSIBILITY    IRAN                                65.0
# WASHINGTON AREA OF RESPONSIBILITY     CHINA, PEOPLES REPUBLIC OF          20.0
# DETROIT AREA OF RESPONSIBILITY        SENEGAL                             20.0
# SAN FRANCISCO AREA OF RESPONSIBILITY  VENEZUELA                           59.0
# PHOENIX AREA OF RESPONSIBILITY        VIETNAM                             19.0
# SALT LAKE CITY AREA OF RESPONSIBILITY CUBA                                54.0
# NEW YORK CITY AREA OF RESPONSIBILITY  MAURITANIA                          17.0
# LOS ANGELES AREA OF RESPONSIBILITY    CHINA, PEOPLES REPUBLIC OF         168.0
# WASHINGTON AREA OF RESPONSIBILITY     CAMEROON                            32.0
#                                       BRAZIL                              15.0
# SAN FRANCISCO AREA OF RESPONSIBILITY  INDIA                              135.0
# CHICAGO AREA OF RESPONSIBILITY        VIETNAM                             15.0
# WASHINGTON AREA OF RESPONSIBILITY     TURKIYE                             14.0
# PHILADELPHIA AREA OF RESPONSIBILITY   MAURITANIA                          14.0
#
# trump_bool                                                        pre_trump_perc_arrests  \
# apprehension_aor                      citizenship_country
# WASHINGTON AREA OF RESPONSIBILITY     INDIA                                     0.097752
# NEW YORK CITY AREA OF RESPONSIBILITY  HAITI                                     0.124224
# WASHINGTON AREA OF RESPONSIBILITY     AFGHANISTAN                               0.097752
#                                       EGYPT                                     0.097752
#                                       CUBA                                      0.195503
# SEATTLE AREA OF RESPONSIBILITY        PERU                                      0.228833
# LOS ANGELES AREA OF RESPONSIBILITY    IRAN                                      0.175953
# WASHINGTON AREA OF RESPONSIBILITY     CHINA, PEOPLES REPUBLIC OF                0.097752
# DETROIT AREA OF RESPONSIBILITY        SENEGAL                                   0.131062
# SAN FRANCISCO AREA OF RESPONSIBILITY  VENEZUELA                                 0.344037
# PHOENIX AREA OF RESPONSIBILITY        VIETNAM                                   0.059347
# SALT LAKE CITY AREA OF RESPONSIBILITY CUBA                                      0.237718
# NEW YORK CITY AREA OF RESPONSIBILITY  MAURITANIA                                0.124224
# LOS ANGELES AREA OF RESPONSIBILITY    CHINA, PEOPLES REPUBLIC OF                0.586510
# WASHINGTON AREA OF RESPONSIBILITY     CAMEROON                                  0.195503
#                                       BRAZIL                                    0.097752
# SAN FRANCISCO AREA OF RESPONSIBILITY  INDIA                                     1.032110
# CHICAGO AREA OF RESPONSIBILITY        VIETNAM                                   0.029542
# WASHINGTON AREA OF RESPONSIBILITY     TURKIYE                                   0.097752
# PHILADELPHIA AREA OF RESPONSIBILITY   MAURITANIA                                0.099602
#
# trump_bool                                                        trump_perc_arrests
# apprehension_aor                      citizenship_country
# WASHINGTON AREA OF RESPONSIBILITY     INDIA                                 0.884956
# NEW YORK CITY AREA OF RESPONSIBILITY  HAITI                                 1.483924
# WASHINGTON AREA OF RESPONSIBILITY     AFGHANISTAN                           0.762045
#                                       EGYPT                                 0.737463
#                                       CUBA                                  1.302852
# SEATTLE AREA OF RESPONSIBILITY        PERU                                  1.848998
# LOS ANGELES AREA OF RESPONSIBILITY    IRAN                                  1.331767
# WASHINGTON AREA OF RESPONSIBILITY     CHINA, PEOPLES REPUBLIC OF            0.516224
# DETROIT AREA OF RESPONSIBILITY        SENEGAL                               0.838993
# SAN FRANCISCO AREA OF RESPONSIBILITY  VENEZUELA                             2.859779
# PHOENIX AREA OF RESPONSIBILITY        VIETNAM                               0.566251
# SALT LAKE CITY AREA OF RESPONSIBILITY CUBA                                  1.640760
# NEW YORK CITY AREA OF RESPONSIBILITY  MAURITANIA                            0.741962
# LOS ANGELES AREA OF RESPONSIBILITY    CHINA, PEOPLES REPUBLIC OF            3.486095
# WASHINGTON AREA OF RESPONSIBILITY     CAMEROON                              0.835792
#                                       BRAZIL                                0.393314
# SAN FRANCISCO AREA OF RESPONSIBILITY  INDIA                                 6.642066
# CHICAGO AREA OF RESPONSIBILITY        VIETNAM                               0.240349
# WASHINGTON AREA OF RESPONSIBILITY     TURKIYE                               0.368732
# PHILADELPHIA AREA OF RESPONSIBILITY   MAURITANIA                            0.466708

# %%
aor_summary_country.groupby(level=0, group_keys=False)['num_increase'].nlargest(5)
# Out:
# apprehension_aor                       citizenship_country
# ATLANTA AREA OF RESPONSIBILITY         MEXICO                        2146.0
#                                        GUATEMALA                     1009.0
#                                        HONDURAS                       783.0
#                                        VENEZUELA                      584.0
#                                        COLOMBIA                       230.0
# BALTIMORE AREA OF RESPONSIBILITY       GUATEMALA                      273.0
#                                        EL SALVADOR                    225.0
#                                        HONDURAS                       147.0
#                                        MEXICO                         137.0
#                                        VENEZUELA                       59.0
# BOSTON AREA OF RESPONSIBILITY          BRAZIL                         690.0
#                                        GUATEMALA                      616.0
#                                        ECUADOR                        464.0
#                                        DOMINICAN REPUBLIC             311.0
#                                        EL SALVADOR                    172.0
# BUFFALO AREA OF RESPONSIBILITY         ECUADOR                        231.0
#                                        MEXICO                         123.0
#                                        GUATEMALA                      120.0
#                                        VENEZUELA                       53.0
#                                        BRAZIL                          27.0
# CHICAGO AREA OF RESPONSIBILITY         MEXICO                        1272.0
#                                        VENEZUELA                      533.0
#                                        GUATEMALA                      503.0
#                                        HONDURAS                       333.0
#                                        NICARAGUA                      136.0
# DALLAS AREA OF RESPONSIBILITY          MEXICO                        2005.0
#                                        VENEZUELA                      898.0
#                                        HONDURAS                       552.0
#                                        GUATEMALA                      447.0
#                                        EL SALVADOR                    263.0
# DENVER AREA OF RESPONSIBILITY          MEXICO                         677.0
#                                        VENEZUELA                      266.0
#                                        COLOMBIA                       152.0
#                                        HONDURAS                       125.0
#                                        GUATEMALA                       98.0
# DETROIT AREA OF RESPONSIBILITY         MEXICO                         589.0
#                                        GUATEMALA                      306.0
#                                        VENEZUELA                      227.0
#                                        HONDURAS                       184.0
#                                        EL SALVADOR                     72.0
# EL PASO AREA OF RESPONSIBILITY         MEXICO                         500.0
#                                        VENEZUELA                      279.0
#                                        CUBA                            93.0
#                                        GUATEMALA                       70.0
#                                        COLOMBIA                        49.0
# HARLINGEN AREA OF RESPONSIBILITY       MEXICO                        1790.0
#                                        HONDURAS                        88.0
#                                        GUATEMALA                       78.0
#                                        EL SALVADOR                     21.0
#                                        CUBA                             7.0
# HOUSTON AREA OF RESPONSIBILITY         MEXICO                        1488.0
#                                        HONDURAS                       922.0
#                                        GUATEMALA                      497.0
#                                        EL SALVADOR                    380.0
#                                        VENEZUELA                      167.0
# HQ AREA OF RESPONSIBILITY              MEXICO                           8.0
#                                        VENEZUELA                        2.0
#                                        COLOMBIA                         0.0
#                                        CONGO                            NaN
#                                        EL SALVADOR                      NaN
# LOS ANGELES AREA OF RESPONSIBILITY     MEXICO                        1645.0
#                                        GUATEMALA                      517.0
#                                        EL SALVADOR                    218.0
#                                        CHINA, PEOPLES REPUBLIC OF     168.0
#                                        COLOMBIA                       137.0
# MIAMI AREA OF RESPONSIBILITY           GUATEMALA                     2039.0
#                                        MEXICO                        1728.0
#                                        HONDURAS                      1094.0
#                                        CUBA                          1001.0
#                                        VENEZUELA                      779.0
# NEW ORLEANS AREA OF RESPONSIBILITY     MEXICO                        1598.0
#                                        GUATEMALA                     1057.0
#                                        HONDURAS                       863.0
#                                        VENEZUELA                      375.0
#                                        EL SALVADOR                    186.0
# NEW YORK CITY AREA OF RESPONSIBILITY   ECUADOR                        289.0
#                                        EL SALVADOR                    198.0
#                                        HONDURAS                       140.0
#                                        VENEZUELA                      133.0
#                                        MEXICO                         122.0
# NEWARK AREA OF RESPONSIBILITY          GUATEMALA                      259.0
#                                        MEXICO                         187.0
#                                        ECUADOR                        181.0
#                                        HONDURAS                       151.0
#                                        COLOMBIA                        92.0
# PHILADELPHIA AREA OF RESPONSIBILITY    MEXICO                         505.0
#                                        GUATEMALA                      401.0
#                                        DOMINICAN REPUBLIC             207.0
#                                        HONDURAS                       192.0
#                                        VENEZUELA                      145.0
# PHOENIX AREA OF RESPONSIBILITY         MEXICO                        1169.0
#                                        GUATEMALA                      222.0
#                                        VENEZUELA                      150.0
#                                        CUBA                            68.0
#                                        NICARAGUA                       53.0
# SALT LAKE CITY AREA OF RESPONSIBILITY  MEXICO                        1135.0
#                                        VENEZUELA                      258.0
#                                        GUATEMALA                      185.0
#                                        HONDURAS                       132.0
#                                        EL SALVADOR                    112.0
# SAN ANTONIO AREA OF RESPONSIBILITY     MEXICO                         946.0
#                                        HONDURAS                       698.0
#                                        VENEZUELA                      567.0
#                                        GUATEMALA                      321.0
#                                        CUBA                           316.0
# SAN DIEGO AREA OF RESPONSIBILITY       MEXICO                         695.0
#                                        GUATEMALA                       91.0
#                                        VENEZUELA                       74.0
#                                        VIETNAM                         32.0
#                                        COLOMBIA                        23.0
# SAN FRANCISCO AREA OF RESPONSIBILITY   MEXICO                         446.0
#                                        INDIA                          135.0
#                                        EL SALVADOR                     92.0
#                                        GUATEMALA                       87.0
#                                        HONDURAS                        80.0
# SEATTLE AREA OF RESPONSIBILITY         MEXICO                         355.0
#                                        VENEZUELA                      107.0
#                                        GUATEMALA                       74.0
#                                        HONDURAS                        73.0
#                                        NICARAGUA                       38.0
# ST. PAUL AREA OF RESPONSIBILITY        MEXICO                         619.0
#                                        GUATEMALA                      375.0
#                                        HONDURAS                       186.0
#                                        ECUADOR                        104.0
#                                        NICARAGUA                      104.0
# WASHINGTON AREA OF RESPONSIBILITY      GUATEMALA                      461.0
#                                        HONDURAS                       430.0
#                                        EL SALVADOR                    410.0
#                                        MEXICO                         303.0
#                                        VENEZUELA                      300.0
# Name: num_increase, dtype: float64

# %% [markdown]
# Creating a plot to look at the country changes for each AOR:

# %%
# so the countries in plots are in the same order, for ease of comparison:
country_order = list(aor_summary_country.reset_index().groupby('citizenship_country')['trump'].sum().sort_values(ascending=False).index)

def country_pre_post_plot(aor_str, interactive=False, save=False):
    aor_country_plot_df = aor_summary_country[['pre_trump','trump']].stack().reset_index().rename(
        columns={0:'num_arrests'})
    
    chart = alt.layer(
            data=aor_country_plot_df[aor_country_plot_df['apprehension_aor']==aor_str]
        )
    
    chart += alt.Chart().mark_line(color='#9E9EA3').encode(
            x=alt.X('num_arrests:Q'),
            y=alt.Y('citizenship_country:N', sort=country_order),
            detail='citizenship_country:N',
        )
        # Add points for life expectancy in 1955 & 2000
    chart += alt.Chart().mark_point(
            size=100,
            opacity=0.5,
            filled=True
        ).encode(
            x=alt.X('num_arrests:Q', title="Number arrests"),
            y=alt.Y('citizenship_country:N', title="", sort=country_order),
            color=alt.Color('trump_bool',
                scale=alt.Scale(
                    domain=['pre_trump','trump'],
                    range=['#2a6ca8', '#bf1515']
                )
            )
        ).properties(width=800, title=aor_str)
    if save:
        chart.save(f'{aor_str}_country_arrest_change.png')
    
    if interactive:
        return chart.interactive()
    return chart
    
    # use chart.interactive() if you want to look into what is happening for the countries with smaller n's. as you can then scroll in

# %%
country_pre_post_plot('NEW YORK CITY AREA OF RESPONSIBILITY', save=True)
# Out:
# alt.LayerChart(...)

# %%
country_pre_post_plot('WASHINGTON AREA OF RESPONSIBILITY', save=True)
# Out:
# alt.LayerChart(...)

# %%
country_pre_post_plot('BOSTON AREA OF RESPONSIBILITY', save=True)
# Out:
# alt.LayerChart(...)

# %%
country_pre_post_plot('ATLANTA AREA OF RESPONSIBILITY', interactive=True)
# Out:
# alt.LayerChart(...)

# %%
country_pre_post_plot('DALLAS AREA OF RESPONSIBILITY', save=True)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ##### Observations:
#
# * Seems like there has been a big increase across most countries, but in particular there are some countries which did not have many arrests at all before that have had huge proportional increases.
# * Looks like the AORs with the biggest prop increases for these countries with lower numbers of arrests overall are the same AORs which saw the biggest overall proportion increase -> could this be an indication that these areas are arresting people from more countries?

# %%
num_countries_pre_post_by_aor = eq_days_pre_post_trump.groupby(['apprehension_aor', 'trump_bool'])['citizenship_country'].nunique().unstack()
num_countries_pre_post_by_aor.columns = [str(c) for c in num_countries_pre_post_by_aor.columns]
num_countries_pre_post_by_aor['delta'] = num_countries_pre_post_by_aor['trump'] - num_countries_pre_post_by_aor['pre_trump']

# %%
num_countries_pre_post_by_aor.sort_values(by='delta', ascending=False)
# Out:
#                                        pre_trump  trump  delta
# apprehension_aor
# NEW YORK CITY AREA OF RESPONSIBILITY          50     88     38
# HOUSTON AREA OF RESPONSIBILITY                47     84     37
# ATLANTA AREA OF RESPONSIBILITY                60     96     36
# BOSTON AREA OF RESPONSIBILITY                 62     98     36
# DALLAS AREA OF RESPONSIBILITY                 64     99     35
# MIAMI AREA OF RESPONSIBILITY                  85    119     34
# BUFFALO AREA OF RESPONSIBILITY                44     78     34
# BALTIMORE AREA OF RESPONSIBILITY              40     71     31
# DENVER AREA OF RESPONSIBILITY                 29     58     29
# SEATTLE AREA OF RESPONSIBILITY                40     69     29
# SALT LAKE CITY AREA OF RESPONSIBILITY         42     71     29
# SAN ANTONIO AREA OF RESPONSIBILITY            43     71     28
# DETROIT AREA OF RESPONSIBILITY                53     81     28
# WASHINGTON AREA OF RESPONSIBILITY             60     86     26
# PHILADELPHIA AREA OF RESPONSIBILITY           78    103     25
# SAN DIEGO AREA OF RESPONSIBILITY              24     49     25
# LOS ANGELES AREA OF RESPONSIBILITY            49     73     24
# PHOENIX AREA OF RESPONSIBILITY                49     72     23
# CHICAGO AREA OF RESPONSIBILITY                74     96     22
# NEW ORLEANS AREA OF RESPONSIBILITY            75     96     21
# SAN FRANCISCO AREA OF RESPONSIBILITY          49     67     18
# ST. PAUL AREA OF RESPONSIBILITY               56     71     15
# NEWARK AREA OF RESPONSIBILITY                 66     80     14
# HARLINGEN AREA OF RESPONSIBILITY              25     35     10
# EL PASO AREA OF RESPONSIBILITY                30     40     10
# HQ AREA OF RESPONSIBILITY                      6      7      1

# %% [markdown]
# **What does this mean** In trump's administration the number of countries people are being arrested from has increased in all AORs - this lends to idea of "indiscriminately"

# %% [markdown]
# #### Change over time (instead of just pre post)
#
# Overall stats of pre and post trump give us some indications of patterns, but we can't see the true picture of what is happening. Next I am going to look at change over time.

# %%
def aor_month_cc(df, top_countries=None, aor_str=None, n=5):
    if aor_str is None:
        aor_str = df['apprehension_aor'].unique().item()
    aor_group = df[df['apprehension_aor'] == aor_str]
    aor_group_cc = aor_group[['apprehension_month_year','citizenship_country']].value_counts().reset_index().rename(columns={'count':'num_arrests'})
    if top_countries is None: # done so I can feed in top countries if I want them to be consisten across aors, rather than unique to the top for that aor
        top_countries = aor_group_cc.groupby('citizenship_country')['num_arrests'].sum().sort_values(ascending=False).head(n).index
    aor_group_cc['summary_country'] = np.where(
            aor_group_cc['citizenship_country'].isin(top_countries), aor_group_cc['citizenship_country'], 'OTHER COUNTRY')
    return aor_group_cc

# %%
COUNTRY_ORDER = ['EL SALVADOR','GUATEMALA','HONDURAS','MEXICO','VENEZUELA','OTHER COUNTRY']

def plot_area_chart(df,aor_str, top_countries=None, save=False):
    aor_summary = aor_month_cc(df, top_countries, aor_str)
    aor_summary['apprehension_month_year'] = aor_summary['apprehension_month_year'].dt.strftime('%Y-%m')
    chart = alt.Chart(aor_summary, title=aor_str).mark_bar().encode(
        x='apprehension_month_year:O',
        y='sum(num_arrests)',
        color=alt.Color('summary_country', sort=COUNTRY_ORDER)).properties(width=800, height=400)
    if save:
        chart.save(figures/f'{aor_str}_monthly_country_arrests.png')
    return chart

# %%
top_countries_overall = lambda n: arrests_df[arrests_df['trump_bool']=='trump']['citizenship_country'].value_counts().head(n).index

# %%
plot_area_chart(arrests_df, 'WASHINGTON AREA OF RESPONSIBILITY', top_countries_overall(5), save=True)
# Out:
# alt.Chart(...)

# %%
plot_area_chart(arrests_df, 'NEW YORK CITY AREA OF RESPONSIBILITY', top_countries_overall(5))
# Out:
# alt.Chart(...)

# %%
plot_area_chart(arrests_df, 'DALLAS AREA OF RESPONSIBILITY', top_countries_overall(5), save=True)
# Out:
# alt.Chart(...)

# %%
plot_area_chart(arrests_df, 'BOSTON AREA OF RESPONSIBILITY', top_countries_overall(5))
# Out:
# alt.Chart(...)

# %% [markdown]
# Other ways to look at this would be:
# * Number of citizenship countries by month by AOR

# %%
num_countries_over_time = arrests_df.groupby(['apprehension_aor','apprehension_month_year'])['citizenship_country'].nunique().reset_index()

num_countries_over_time['apprehension_month_year'] = num_countries_over_time['apprehension_month_year'].dt.strftime('%Y-%m')

# %%
chart = alt.Chart(num_countries_over_time).mark_line().encode(
    x=alt.X('apprehension_month_year:O', title=None, axis=alt.Axis( grid = False, values=['2025-01'])),
    y=alt.Y('citizenship_country', title='Number of nationalities'),
    color=alt.Color('apprehension_aor', legend=None),
    tooltip=['apprehension_aor']
).properties(
    width=200,
    height=200,
).facet(
    facet=alt.Facet('apprehension_aor', title=None),
    columns=4,
        title={
        'text':'Some AORs have had huge jumps in number of nationalities they are arresting under Trump',
        'subtitle':['Change in monthly number of unique citizenship countries for each ICE AOR', '']}
).resolve_axis(
    x='independent')

chart.save(figures/"aor_num_nationalities_monthly.svg")

chart
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ### Next steps:
#
# * Check pre-post equal number of days makes sense and adjust if needed to account for holidays, weekends, seasonality etc.
# * Significance tests:
#   * Number of nationalities: if the number of nationalities is an area we want to focus on, we can identify the areas that have seen a significant shift post Trump (rather than just gradually following the pre trump trend of increasing) through Regression Discontinuity or Interrupted Time Series (probably Interrupted time series because close to the inaugeration could be some overlaps of cases in progress etc. (need to think about how quickly we would expect to see the change, and what a reasonable comparison is)
#   * Which country increases in number of arrests are significant, and for which AORs? - paired t-tests
# * There is a lot more that could be done in this analysis - I have only really scratched the surface. Particular areas I would be interested in focusing on:
#   * Bringing in data on estimated numbers of people of each nationality by state - in addition to overall numbers of nationalities increasing, there are some really large increases in numbers of people from particular nationalities being arrested (e.g. Brazillians in Boston AOR). I would like to know whether these big increases are due to targeted programs, or whether they are simply a reflection of the number of people of each nationality living in that area.
#   * Looking into more detail for specific AORs - while some AORs seem to have had a big increase in arrests (and number of nationalities) since January (e.g. Washington AOR), others have seen big jumps in particular months (e.g. Boston in May; New York in June). I would like to talk to the team on the ground to understand more about whether this is related to any particular program (e.g. could these represent times when the Local police forces are being coopted?) - there is a lot more detail to go into here .

# %% [markdown]
# ## Question 2
# Select one question from Task 3 Steps 2-4 and complete the analysis.
#
# **Question:**
# Is there evidence that ICE are accelerating deportations?
# 1. Has the proportion of those arrested that are deported increased over time?
# 2. For those that are deported, has the average length of time between arrest data and deportation date been decreasing over time?

# %%
arrests_df['departed_date']
# Out:
# 0        2024-08-19
# 1        2024-10-22
# 2        2025-06-10
# 3               NaT
# 4        2025-02-01
#             ...
# 265180          NaT
# 265181          NaT
# 265182          NaT
# 265183          NaT
# 265184          NaT
# Name: departed_date, Length: 265185, dtype: datetime64[ns]

# %% [markdown]
# #### Proportion of arrests leading to a deportation:

# %%
eq_days_pre_post_trump['deported_bool'] = np.where(eq_days_pre_post_trump['departure_country'].isna(), False, True)

# %%
eq_days_pre_post_trump[['deported_bool', 'trump_bool']].value_counts().unstack()
# Out:
# trump_bool     pre_trump  trump
# deported_bool
# False              14765  57732
# True               29883  53835

# %%
eq_days_pre_post_trump['departed_month'] = eq_days_pre_post_trump['departed_date'].dt.to_period('M').astype(str)

# %%
month_prop_deported = eq_days_pre_post_trump[['apprehension_month_year', 'deported_bool']].value_counts().reset_index()
month_prop_deported['apprehension_month_year'] = month_prop_deported['apprehension_month_year'].astype(str)

# %%
alt.Chart(month_prop_deported).mark_bar().encode(
    x='apprehension_month_year:O',
    y=alt.Y('count').stack("normalize"),
    color='deported_bool').properties(width=400, height=400)
# Out:
# alt.Chart(...)

# %% [markdown]
# **Note** - there is a clear time period factor that needs taking into account here - it makes sense that May and June have lower proportions of deportations as deportations can take more than a month from arrest

# %%
alt.Chart(month_prop_deported).mark_bar().encode(
    x='apprehension_month_year:O',
    y=alt.Y('count'),
    color='deported_bool').properties(width=400, height=400)
# Out:
# alt.Chart(...)

# %% [markdown]
# **Conclusion:**
#
# The data actually shows the opposite of my initial assertion, as proportion of arrests that lead to deportation has decreased since the start of the Trump administration.
#
# This makes sense, as the overall number of arrests has increased (and if "indiscriminate" arrests are happening, then there are likely a smaller proportion that actually have a reason for arrest and deportation.
#
# Limitations:
# * Time period bias - this could be due to the fact that the deportations have not happed **yet** for recent arrests

# %% [markdown]
# #### Is the time between arrest to deportation date decreasing?

# %%
eq_days_pre_post_trump['days_arrest_to_deportation'] = (eq_days_pre_post_trump['departed_date'] - eq_days_pre_post_trump['apprehension_date']).dt.days

# %%
eq_days_pre_post_trump.groupby('trump_bool').agg({'days_arrest_to_deportation': 'mean'})
# Out:
#             days_arrest_to_deportation
# trump_bool
# pre_trump                    50.675879
# trump                        26.396211

# %%
arrests_df['deported_bool'] = np.where(arrests_df['departure_country'].isna(), False, True)
arrests_df['departed_month'] = arrests_df['departed_date'].dt.to_period('M').astype(str)
arrests_df['days_arrest_to_deportation'] = (arrests_df['departed_date'] - arrests_df['apprehension_date']).dt.days

# %%
deported_df = arrests_df[arrests_df['deported_bool']==True]

# %%
month_time_to_departed = deported_df.groupby('apprehension_month_year').agg({'days_arrest_to_deportation':'mean'}).reset_index()
month_time_to_departed['apprehension_month_year'] = month_time_to_departed['apprehension_month_year'].astype(str)

# %%
plot_timeframe_df = deported_df[
    (deported_df['apprehension_date'].dt.date >= datetime.strptime('2024-06-01', '%Y-%m-%d').date()) & 
    (deported_df['apprehension_date'].dt.date < datetime.strptime('2025-06-01', '%Y-%m-%d').date())]

# %%
day_time_to_departed = plot_timeframe_df.groupby('apprehension_day').agg({'days_arrest_to_deportation':'mean'})
day_time_to_departed_rolling_average = day_time_to_departed.rolling(window=7).mean().reset_index().rename(columns={'days_arrest_to_deportation':'rolling_average'})
day_time_to_departed_rolling_average['apprehension_day'] = day_time_to_departed_rolling_average['apprehension_day'].astype(str)

# %%
chart = alt.Chart(day_time_to_departed_rolling_average).mark_line().encode(
        x=alt.X('apprehension_day:T', axis=alt.Axis(labelAngle=-45, format="%B-%Y"), title='Apprehension Date'),
        y=alt.Y('rolling_average', title='Number of days between arrest to deportation date', scale=alt.Scale(domain=[0,70]))
    ).properties(
        width=1000,
        height=400,
        title={
            'text':'There has been a huge acceleration in speed of deportation since the beginning of the Trump administration',
            'subtitle':'7 day rolling average of number of days, shown by the date of arrest'})

chart.save(figures/"time_from_arrests_to_deportation.png")

chart
# Out:
# alt.Chart(...)

# %%
chart = alt.layer(
            data=aor_pre_post_num_days
        )
    
chart += alt.Chart().mark_line(color='#9E9EA3').encode(
            x=alt.X('days_arrest_to_deportation:Q'),
            y=alt.Y('apprehension_aor:N'),
            detail='apprehension_aor:N',
        )

chart += alt.Chart().mark_point(
            size=100,
            opacity=0.5,
            filled=True
        ).encode(
            x=alt.X('days_arrest_to_deportation:Q'),
            y=alt.Y('apprehension_aor:N', title="").sort('x'),
            color=alt.Color('trump_bool',
                scale=alt.Scale(
                    domain=['pre_trump','trump'],
                    range=['#2a6ca8', '#bf1515']
                )
            )
        ).properties(
            width=800, 
            title={
                'text':'All AORs (appart from LA) have seen an increase in speed of deportation', 
                'subtitle':'Change in time between arrest to deportation before and since Trump administration',
                })

chart.save(figures/'aor_change_num_days_arrest_to_deportation.png')

chart
# Out:
# alt.LayerChart(...)

# %%
aor_pre_post_num_days = eq_days_pre_post_trump.groupby(['apprehension_aor', 'trump_bool']).agg({'days_arrest_to_deportation':'mean'}).reset_index()
aor_pre_post_num_arrests = eq_days_pre_post_trump[eq_days_pre_post_trump['deported_bool']==True].groupby(['apprehension_aor', 'trump_bool']).agg({'days_arrest_to_deportation':'count'}).reset_index()

chart = alt.Chart(aor_pre_post_num_arrests).mark_bar(opacity=0.6).encode(
    x=alt.X('days_arrest_to_deportation', title='Number of deportations'),
    y=alt.Y('apprehension_aor'),
    color='trump_bool').properties(
        title = {
            'text': 'All AORs have had more deportations during the Trump administration than in the same time before',
            'subtitle':['Number of deportations by AOR, split by number during Trump administration, and before', '']})

chart.save(figures/'aor_number_deportations.png')

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Limitations and next steps:
#
# #### Limitations
# * Bias of time since arrest - we might only be seeing the deportations that are happening quickly, and it could be that more of the arrests will lead to deportations that will happen in a longer time period (but are not shown in the data yet). From the final chart we can see that there are still more deportations happening under Trump, but as a proportion of total arrests this has decreased, which could be due to more indiscriminate arrests, or it could be because we will see more deportations for these arrests but they are taking longer.
#
#
# #### Next steps:
# Again, I am only really scratching the surface of this analysis. Things I'd like to look into:
# * Does nationality have any impact on time to deportation?
# * Are arrests that are done in conjunction with local and state law enforcement more or less likely to result in a deportation?
