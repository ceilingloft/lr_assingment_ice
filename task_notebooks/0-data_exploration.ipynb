# %% [markdown]
# # 0 - Data Exploration

# %%
import numpy as np
import pandas as pd

# %%
arrests_df = pd.read_csv('../data/arrests-0923-0625.csv', parse_dates=['Apprehension Date','Departed Date'])

# %% [markdown]
# **NB** - see note in README - converting to csv has messed with the times (24 hour clock going to 12 hour clock). The dates are fine though, so this can be used as long as not using time of arrest (for that analysis we should use the .xlsx file)

# %%
arrests_df.head()
# Out:
#     Apprehension Date Apprehension State  Apprehension County  \
# 0 2024-08-07 09:43:00           VIRGINIA                  NaN
# 1 2024-10-19 08:33:00              TEXAS                  NaN
# 2 2025-04-15 10:08:00         NEW JERSEY                  NaN
# 3 2025-06-03 09:20:00          MINNESOTA                  NaN
# 4 2025-01-21 05:41:00                NaN                  NaN
#
#                     Apprehension AOR               Final Program  \
# 0  Washington Area of Responsibility  ERO Criminal Alien Program
# 1     Houston Area of Responsibility  ERO Criminal Alien Program
# 2      Newark Area of Responsibility  ERO Criminal Alien Program
# 3    St. Paul Area of Responsibility         Fugitive Operations
# 4       Miami Area of Responsibility  ERO Criminal Alien Program
#
#   Final Program Group        Apprehension Method  \
# 0                 ICE       Non-Custodial Arrest
# 1                 ICE    CAP Local Incarceration
# 2                 ICE  CAP Federal Incarceration
# 3                 ICE       Non-Custodial Arrest
# 4                 ICE    CAP Local Incarceration
#
#        Apprehension Criminality                           Case Status  \
# 0          1 Convicted Criminal  8-Excluded/Removed - Inadmissibility
# 1          1 Convicted Criminal    6-Deported/Removed - Deportability
# 2          1 Convicted Criminal  8-Excluded/Removed - Inadmissibility
# 3  3 Other Immigration Violator                                ACTIVE
# 4    2 Pending Criminal Charges       3-Voluntary Departure Confirmed
#
#                                        Case Category  ... Final Order Date  \
# 0                        [16] Reinstated Final Order  ...       10/18/1999
# 1                        [16] Reinstated Final Order  ...       10/10/2023
# 2                        [16] Reinstated Final Order  ...       04/15/2025
# 3    [8G] Expedited Removal - Credible Fear Referral  ...       06/03/2025
# 4  [8C] Excludable / Inadmissible - Administrativ...  ...       02/01/2025
#
#           Birth Date Birth Year Citizenship Country  Gender  \
# 0  (b)(6), (b)(7)(C)       1981            HONDURAS    Male
# 1  (b)(6), (b)(7)(C)       1984              MEXICO    Male
# 2  (b)(6), (b)(7)(C)       1988  DOMINICAN REPUBLIC    Male
# 3  (b)(6), (b)(7)(C)       1985            COLOMBIA  Female
# 4  (b)(6), (b)(7)(C)       1983              MEXICO    Male
#
#                           Apprehension Site Landmark  Alien File Number  \
# 0                     HBG GENERAL AREA, NON-SPECIFIC  (b)(6), (b)(7)(C)
# 1                    HARRIS COUNTY JAIL, HOUSTON, TX  (b)(6), (b)(7)(C)
# 2                          FORT DIX EAST, NEW JERSEY  (b)(6), (b)(7)(C)
# 3                     SPM GENERAL AREA, NON-SPECIFIC  (b)(6), (b)(7)(C)
# 4  MIAMI DADE COUNTY JAIL TURNER GUILFORD KNIGHT ...  (b)(6), (b)(7)(C)
#
#                     EID Case ID                EID Subject ID  \
# 0  (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 1  (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 2  (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 3  (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 4  (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
#
#                           Unique Identifier
# 0  0000b34edd657d516c02b13a7c352d62d0effcb6
# 1  0000ba6e459998a6046d185d82cf4349de1479d0
# 2  0000c3d23fb0e444864559575900d410c4e8490f
# 3  0000d3dbf8033b5f209f6547ffee5b84feb4f599
# 4  000104d730bf021326c6dc0deb3dd575304136b5
#
# [5 rows x 23 columns]

# %%
arrests_df.columns
# Out:
# Index(['Apprehension Date', 'Apprehension State', 'Apprehension County',
#        'Apprehension AOR', 'Final Program', 'Final Program Group',
#        'Apprehension Method', 'Apprehension Criminality', 'Case Status',
#        'Case Category', 'Departed Date', 'Departure Country',
#        'Final Order Yes No', 'Final Order Date', 'Birth Date', 'Birth Year',
#        'Citizenship Country', 'Gender', 'Apprehension Site Landmark',
#        'Alien File Number', 'EID Case ID', 'EID Subject ID',
#        'Unique Identifier'],
#       dtype='object')

# %%
arrests_df.shape
# Out:
# (265226, 23)

# %% [markdown]
# ### How complete is the data?

# %%
arrests_df.isna().sum().sort_values()
# Out:
# Apprehension Date                  0
# Gender                             0
# Citizenship Country                0
# Final Program                      0
# Final Program Group                0
# Apprehension Method                0
# Apprehension Criminality           0
# Birth Year                         0
# Birth Date                         0
# EID Subject ID                     0
# Alien File Number               2023
# Unique Identifier               2023
# Final Order Yes No              3898
# Case Category                   3898
# Case Status                     3898
# EID Case ID                     3898
# Apprehension AOR                5903
# Apprehension Site Landmark      6100
# Apprehension State             56243
# Final Order Date              104937
# Departed Date                 119909
# Departure Country             119947
# Apprehension County           265226
# dtype: int64

# %% [markdown]
# #### Observations:
# * Location variables have quite a lot of missing: `Apprehension State`, `Apprehension Site Landmark`, `Apprehension AOR`
# * `Unique Identifier` missing for 2023 rows - docs say: *"based on Alien Registration Number (A-number). A-numbers are assigned to noncitizens by ICE or USCIS; undocumented noncitizens who have not interacted with the U.S. government, as well as people on nonimmigrant visas"* (this tracks as same number of missing for `Alien File Number`)  **Need to keep this in mind**
#
#
# #### Is every row unique?

# %%
arrests_df['Unique Identifier'].value_counts().head()
# Out:
# Unique Identifier
# 1e2ec1831c1fd33fdb93b412699a798db3544957    7
# 45c6d66afff974e4fea3a5daca554031dd2f61ff    5
# 26d8a297a31da2d298cc5af37176920d34cb088f    5
# 1007639d0d35049ada17e291e3c201542ff443b1    5
# 1604e1b821a91b42ac5543a4a59e143633309dc8    5
# Name: count, dtype: int64

# %%
arrests_df[arrests_df['Unique Identifier']=='1604e1b821a91b42ac5543a4a59e143633309dc8']
# Out:
#         Apprehension Date Apprehension State  Apprehension County  \
# 22612 2023-12-19 12:25:00         CALIFORNIA                  NaN
# 22613 2024-04-01 10:35:00         CALIFORNIA                  NaN
# 22614 2024-04-01 09:14:00                NaN                  NaN
# 22615 2024-08-05 10:35:00         CALIFORNIA                  NaN
# 22616 2025-06-17 11:12:00         CALIFORNIA                  NaN
#
#                          Apprehension AOR               Final Program  \
# 22612  Los Angeles Area of Responsibility  ERO Criminal Alien Program
# 22613  Los Angeles Area of Responsibility   Alternatives to Detention
# 22614  Los Angeles Area of Responsibility   Alternatives to Detention
# 22615  Los Angeles Area of Responsibility  ERO Criminal Alien Program
# 22616  Los Angeles Area of Responsibility  ERO Criminal Alien Program
#
#       Final Program Group      Apprehension Method Apprehension Criminality  \
# 22612                 ICE  CAP Local Incarceration     1 Convicted Criminal
# 22613                 ICE     Non-Custodial Arrest     1 Convicted Criminal
# 22614                 ICE     Non-Custodial Arrest     1 Convicted Criminal
# 22615                 ICE     Non-Custodial Arrest     1 Convicted Criminal
# 22616                 ICE     Non-Custodial Arrest     1 Convicted Criminal
#
#       Case Status                                      Case Category  ...  \
# 22612      ACTIVE  [8C] Excludable / Inadmissible - Administrativ...  ...
# 22613      ACTIVE  [8C] Excludable / Inadmissible - Administrativ...  ...
# 22614      ACTIVE  [8C] Excludable / Inadmissible - Administrativ...  ...
# 22615      ACTIVE  [8C] Excludable / Inadmissible - Administrativ...  ...
# 22616      ACTIVE  [8C] Excludable / Inadmissible - Administrativ...  ...
#
#       Final Order Date         Birth Date Birth Year Citizenship Country  \
# 22612       10/14/1998  (b)(6), (b)(7)(C)       1977             VIETNAM
# 22613       10/14/1998  (b)(6), (b)(7)(C)       1977             VIETNAM
# 22614       10/14/1998  (b)(6), (b)(7)(C)       1977             VIETNAM
# 22615       10/14/1998  (b)(6), (b)(7)(C)       1977             VIETNAM
# 22616       10/14/1998  (b)(6), (b)(7)(C)       1977             VIETNAM
#
#       Gender                     Apprehension Site Landmark  \
# 22612   Male  LOS ANGELES COUNTY GENERAL AREA, NON-SPECIFIC
# 22613   Male                 SAA GENERAL AREA, NON-SPECIFIC
# 22614   Male                 SAA GENERAL AREA, NON-SPECIFIC
# 22615   Male                 SAA GENERAL AREA, NON-SPECIFIC
# 22616   Male                 SAA GENERAL AREA, NON-SPECIFIC
#
#        Alien File Number                   EID Case ID  \
# 22612  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C), (b)(7)(E)
# 22613  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C), (b)(7)(E)
# 22614  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C), (b)(7)(E)
# 22615  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C), (b)(7)(E)
# 22616  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C), (b)(7)(E)
#
#                      EID Subject ID                         Unique Identifier
# 22612  (b)(6), (b)(7)(C), (b)(7)(E)  1604e1b821a91b42ac5543a4a59e143633309dc8
# 22613  (b)(6), (b)(7)(C), (b)(7)(E)  1604e1b821a91b42ac5543a4a59e143633309dc8
# 22614  (b)(6), (b)(7)(C), (b)(7)(E)  1604e1b821a91b42ac5543a4a59e143633309dc8
# 22615  (b)(6), (b)(7)(C), (b)(7)(E)  1604e1b821a91b42ac5543a4a59e143633309dc8
# 22616  (b)(6), (b)(7)(C), (b)(7)(E)  1604e1b821a91b42ac5543a4a59e143633309dc8
#
# [5 rows x 23 columns]

# %% [markdown]
# Some seem to be duplicated rows, and others are actual multiple arrests for some people

# %%
arrests_df[arrests_df.duplicated()].shape
# Out:
# (41, 23)

# %%
arrests_df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Do all the columns hold useful information?

# %%
arrests_df.isna().all()
# Out:
# Apprehension Date             False
# Apprehension State            False
# Apprehension County            True
# Apprehension AOR              False
# Final Program                 False
# Final Program Group           False
# Apprehension Method           False
# Apprehension Criminality      False
# Case Status                   False
# Case Category                 False
# Departed Date                 False
# Departure Country             False
# Final Order Yes No            False
# Final Order Date              False
# Birth Date                    False
# Birth Year                    False
# Citizenship Country           False
# Gender                        False
# Apprehension Site Landmark    False
# Alien File Number             False
# EID Case ID                   False
# EID Subject ID                False
# Unique Identifier             False
# dtype: bool

# %%
arrests_df.nunique()
# Out:
# Apprehension Date             166619
# Apprehension State                61
# Apprehension County                0
# Apprehension AOR                  26
# Final Program                     14
# Final Program Group                1
# Apprehension Method               25
# Apprehension Criminality           3
# Case Status                       13
# Case Category                     29
# Departed Date                    683
# Departure Country                186
# Final Order Yes No                 2
# Final Order Date                9721
# Birth Date                         1
# Birth Year                        90
# Citizenship Country              194
# Gender                             3
# Apprehension Site Landmark      4968
# Alien File Number                  1
# EID Case ID                        1
# EID Subject ID                     1
# Unique Identifier             249872
# dtype: int64

# %% [markdown]
# #### Looking into the columns that only have one value to check if it's useful info:

# %%
nunique = arrests_df.nunique().reset_index().rename(columns={'index':'column', 0:'nunique'})
nunique_1_cols = nunique['column'][nunique['nunique']==1]
arrests_df[nunique_1_cols]
# Out:
#        Final Program Group         Birth Date  Alien File Number  \
# 0                      ICE  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C)
# 1                      ICE  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C)
# 2                      ICE  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C)
# 3                      ICE  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C)
# 4                      ICE  (b)(6), (b)(7)(C)  (b)(6), (b)(7)(C)
# ...                    ...                ...                ...
# 265221                 ICE  (b)(6), (b)(7)(C)                NaN
# 265222                 ICE  (b)(6), (b)(7)(C)                NaN
# 265223                 ICE  (b)(6), (b)(7)(C)                NaN
# 265224                 ICE  (b)(6), (b)(7)(C)                NaN
# 265225                 ICE  (b)(6), (b)(7)(C)                NaN
#
#                          EID Case ID                EID Subject ID
# 0       (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 1       (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 2       (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 3       (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 4       (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# ...                              ...                           ...
# 265221  (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
# 265222                           NaN  (b)(6), (b)(7)(C), (b)(7)(E)
# 265223                           NaN  (b)(6), (b)(7)(C), (b)(7)(E)
# 265224                           NaN  (b)(6), (b)(7)(C), (b)(7)(E)
# 265225  (b)(6), (b)(7)(C), (b)(7)(E)  (b)(6), (b)(7)(C), (b)(7)(E)
#
# [265226 rows x 5 columns]

# %%
nunique_1_cols
# Out:
# 5     Final Program Group
# 14             Birth Date
# 19      Alien File Number
# 20            EID Case ID
# 21         EID Subject ID
# Name: column, dtype: object

# %% [markdown]
# Seems it is mainly redacted information, and the Final Program Group just tells us that all of these arrests are done by ICE (which we already know). So we can remove these columns from the dataset to focus on the variables that have more information

# %%
ARRESTS_KEY_COLS = [c for c in arrests_df.columns if 
                        c not in list(nunique_1_cols) and 
                            not arrests_df[c].isna().all()]
ARRESTS_KEY_COLS
# Out:
# ['Apprehension Date',
#  'Apprehension State',
#  'Apprehension AOR',
#  'Final Program',
#  'Apprehension Method',
#  'Apprehension Criminality',
#  'Case Status',
#  'Case Category',
#  'Departed Date',
#  'Departure Country',
#  'Final Order Yes No',
#  'Final Order Date',
#  'Birth Year',
#  'Citizenship Country',
#  'Gender',
#  'Apprehension Site Landmark',
#  'Unique Identifier']

# %% [markdown]
# #### Quick eyeballing of value counts for these cols to check the data

# %%
for c in ARRESTS_KEY_COLS:
    if arrests_df[c].nunique() < 300: # don't want to print out all the dates and IDs
        print(f"""
        {arrests_df[c].value_counts()}

        """)
# Out:
#         Apprehension State
# TEXAS                             52778
# FLORIDA                           20432
# CALIFORNIA                        14433
# NEW YORK                          10006
# GEORGIA                            7053
#                                   ...
# FEDERATED STATES OF MICRONESIA       15
# ARMED SERVICES - PACIFIC              3
# ARMED FORCES - EUROPE                 2
# TAMAULIPAS                            1
# MEXICO                                1
# Name: count, Length: 61, dtype: int64
#
#
#
#         Apprehension AOR
# Miami Area of Responsibility             26925
# New Orleans Area of Responsibility       23598
# Dallas Area of Responsibility            23185
# Houston Area of Responsibility           21785
# Chicago Area of Responsibility           18370
# Atlanta Area of Responsibility           16596
# San Antonio Area of Responsibility       15161
# Harlingen Area of Responsibility         11607
# Los Angeles Area of Responsibility       11575
# Newark Area of Responsibility             8506
# Phoenix Area of Responsibility            8351
# New York City Area of Responsibility      8101
# Salt Lake City Area of Responsibility     7664
# Boston Area of Responsibility             7148
# Washington Area of Responsibility         6955
# Philadelphia Area of Responsibility       6240
# St. Paul Area of Responsibility           6124
# Detroit Area of Responsibility            5400
# San Francisco Area of Responsibility      5277
# Denver Area of Responsibility             4582
# El Paso Area of Responsibility            4383
# Baltimore Area of Responsibility          3756
# Seattle Area of Responsibility            3669
# Buffalo Area of Responsibility            2200
# San Diego Area of Responsibility          2132
# HQ Area of Responsibility                   33
# Name: count, dtype: int64
#
#
#
#         Final Program
# ERO Criminal Alien Program             162433
# Fugitive Operations                     39776
# Non-Detained Docket Control             33165
# Alternatives to Detention               12761
# Detained Docket Control                  8972
# 287G Program                             4934
# Mobile Criminal Alien Team               2214
# Juvenile                                  444
# ERO Criminal Prosecutions                 304
# Detention and Deportation                 159
# Law Enforcement Area Response Units        45
# 287g Task Force                            10
# Violent Criminal Alien Section              5
# Joint Criminal Alien Response Team          4
# Name: count, dtype: int64
#
#
#
#         Apprehension Method
# CAP Local Incarceration                        112103
# Non-Custodial Arrest                            56910
# Located                                         31405
# CAP Federal Incarceration                       23408
# CAP State Incarceration                         10419
# Other efforts                                    9018
# ERO Reprocessed Arrest                           8875
# 287(g) Program                                   6313
# Probation and Parole                             3833
# Law Enforcement Agency Response Unit              845
# Other Task Force                                  505
# Patrol Border                                     477
# Other Agency (turned over to INS)                 444
# Worksite Enforcement                              252
# Inspections                                       127
# Anti-Smuggling                                     84
# Traffic Check                                      62
# Organized Crime Drug Enforcement Task Force        52
# Patrol Interior                                    51
# Boat Patrol                                        14
# Transportation Check Aircraft                      13
# Crewman/Stowaway                                    5
# Transportation Check Bus                            5
# Criminal Alien Program                              4
# Transportation Check Passenger Train                2
# Name: count, dtype: int64
#
#
#
#         Apprehension Criminality
# 1 Convicted Criminal            123124
# 3 Other Immigration Violator     73718
# 2 Pending Criminal Charges       68384
# Name: count, dtype: int64
#
#
#
#         Case Status
# ACTIVE                                          111110
# 8-Excluded/Removed - Inadmissibility             96641
# 6-Deported/Removed - Deportability               36850
# 3-Voluntary Departure Confirmed                   6580
# 9-VR Witnessed                                    5072
# E-Charging Document Canceled by ICE               2136
# A-Proceedings Terminated                          1828
# B-Relief Granted                                   835
# 5-Title 50 Expulsion                                88
# L-Legalization - Permanent Residence Granted        87
# 0-Withdrawal Permitted - I-275 Issued               49
# 7-Died                                              38
# Z-SAW - Permanent Residence Granted                 14
# Name: count, dtype: int64
#
#
#
#         Case Category
# [8C] Excludable / Inadmissible - Administrative Final Order Issued             76599
# [16] Reinstated Final Order                                                    57999
# [8B] Excludable / Inadmissible - Under Adjudication by IJ                      51343
# [8A] Excludable / Inadmissible - Hearing Not Commenced                         18909
# [3] Deportable - Administratively Final Order                                  12739
# [8G] Expedited Removal - Credible Fear Referral                                 8215
# [2A] Deportable - Under Adjudication by IJ                                      8024
# [8F] Expedited Removal                                                          7995
# [11] Administrative Deportation / Removal                                       6051
# [9] VR Under Safeguards                                                         5363
# [8K] Expedited Removal Terminated due to Credible Fear Finding / NTA Issued     2187
# [10] Visa Waiver Deportation / Removal                                          1211
# [8D] Excludable / Inadmissible - Under Adjudication by BIA                      1208
# [8E] Inadmissible - ICE Fugitive                                                1173
# [1A] Voluntary Departure - Un-Expired and Un-Extended Departure Period           985
# [2B] Deportable - Under Adjudication by BIA                                      408
# [5F] Unable to Obtain Travel Document                                            316
# [5C] Relief Granted - Withholding of Deportation / Removal                        94
# [8H] Expedited Removal - Status Claim Referral                                    90
# [8I] Inadmissible - ICE Fugitive - Expedited Removal                              78
# [5D] Final Order of Deportation / Removal - Deferred Action Granted               77
# [12] Judicial Deportation / Removal                                               72
# [5E] Relief Granted - Extended Voluntary Departure                                62
# [5B] Removable - ICE Fugitive                                                     57
# [14] Crewmen, Stowaways, S-Visa Holders, 235(c) Cases                             36
# [5A] Referred for Investigation - No Show for Hearing - No Final Order            18
# [15] Terrorist Court Case (Title 5)                                               10
# [1B] Voluntary Departure - Extended Departure Period                               7
# [13] Section 250 Removal                                                           2
# Name: count, dtype: int64
#
#
#
#         Departure Country
# MEXICO                      73037
# GUATEMALA                   20143
# HONDURAS                    19256
# EL SALVADOR                  7141
# COLOMBIA                     3664
#                             ...
# CHRISTMAS ISLAND                1
# NAMIBIA                         1
# ESWATINI                        1
# TURKS AND CAICOS ISLANDS        1
# LIECHTENSTEIN                   1
# Name: count, Length: 186, dtype: int64
#
#
#
#         Final Order Yes No
# YES    160292
# NO     101036
# Name: count, dtype: int64
#
#
#
#         Birth Year
# 1992    9866
# 1994    9804
# 1993    9752
# 1997    9637
# 1995    9532
#         ...
# 1936       2
# 1938       1
# 1934       1
# 1939       1
# 1937       1
# Name: count, Length: 90, dtype: int64
#
#
#
#         Citizenship Country
# MEXICO            101036
# GUATEMALA          32638
# HONDURAS           29628
# VENEZUELA          15238
# NICARAGUA          14688
#                    ...
# ESWATINI               1
# BRUNEI                 1
# AUSTRIA                1
# SINT EUSTATIUS         1
# ANDORRA                1
# Name: count, Length: 194, dtype: int64
#
#
#
#         Gender
# Male       230238
# Female      33794
# Unknown      1194
# Name: count, dtype: int64

# %% [markdown]
# #### Checking data quality:
#
# ##### 1. `Citizenship Country`

# %%
np.sort(arrests_df['Citizenship Country'].unique())
# Out:
# array(['AFGHANISTAN', 'ALBANIA', 'ALGERIA', 'ANDORRA', 'ANGOLA',
#        'ANGUILLA', 'ANTIGUA-BARBUDA', 'ARGENTINA', 'ARMENIA', 'AUSTRALIA',
#        'AUSTRIA', 'AZERBAIJAN', 'BAHAMAS', 'BAHRAIN', 'BANGLADESH',
#        'BARBADOS', 'BELARUS', 'BELGIUM', 'BELIZE', 'BENIN', 'BHUTAN',
#        'BOLIVIA', 'BOSNIA-HERZEGOVINA', 'BOTSWANA', 'BRAZIL',
#        'BRITISH VIRGIN ISLANDS', 'BRUNEI', 'BULGARIA', 'BURKINA FASO',
#        'BURMA', 'BURUNDI', 'CAMBODIA', 'CAMEROON', 'CANADA', 'CAPE VERDE',
#        'CENTRAL AFRICAN REPUBLIC', 'CHAD', 'CHILE',
#        'CHINA, PEOPLES REPUBLIC OF', 'COLOMBIA', 'CONGO', 'COSTA RICA',
#        'CROATIA', 'CUBA', 'CURACAO', 'CYPRUS', 'CZECH REPUBLIC',
#        'CZECHOSLOVAKIA', 'DEM REP OF THE CONGO', 'DENMARK', 'DJIBOUTI',
#        'DOMINICA', 'DOMINICAN REPUBLIC', 'EAST TIMOR', 'ECUADOR', 'EGYPT',
#        'EL SALVADOR', 'EQUATORIAL GUINEA', 'ERITREA', 'ESTONIA',
#        'ESWATINI', 'ETHIOPIA', 'FIJI', 'FINLAND', 'FRANCE',
#        'FRENCH GUIANA', 'FRENCH POLYNESIA', 'GABON', 'GAMBIA', 'GEORGIA',
#        'GERMANY', 'GHANA', 'GREECE', 'GRENADA', 'GUADELOUPE', 'GUATEMALA',
#        'GUINEA', 'GUINEA-BISSAU', 'GUYANA', 'HAITI', 'HONDURAS',
#        'HONG KONG', 'HUNGARY', 'ICELAND', 'INDIA', 'INDONESIA', 'IRAN',
#        'IRAQ', 'IRELAND', 'ISRAEL', 'ITALY', 'IVORY COAST', 'JAMAICA',
#        'JAPAN', 'JORDAN', 'KAZAKHSTAN', 'KENYA', 'KOREA', 'KOSOVO',
#        'KUWAIT', 'KYRGYZSTAN', 'LAOS', 'LATVIA', 'LEBANON', 'LIBERIA',
#        'LIBYA', 'LITHUANIA', 'MALAWI', 'MALAYSIA', 'MALI', 'MALTA',
#        'MARSHALL ISLANDS', 'MAURITANIA', 'MAURITIUS', 'MEXICO',
#        'MICRONESIA, FEDERATED STATES OF', 'MOLDOVA', 'MONGOLIA',
#        'MONTENEGRO', 'MONTSERRAT', 'MOROCCO', 'MOZAMBIQUE', 'NAMIBIA',
#        'NEPAL', 'NETHERLANDS', 'NETHERLANDS ANTILLES', 'NEW ZEALAND',
#        'NICARAGUA', 'NIGER', 'NIGERIA', 'NORTH MACEDONIA', 'NORWAY',
#        'OMAN', 'PAKISTAN', 'PALAU', 'PANAMA', 'PAPUA NEW GUINEA',
#        'PARAGUAY', 'PERU', 'PHILIPPINES', 'POLAND', 'PORTUGAL', 'ROMANIA',
#        'RUSSIA', 'RWANDA', 'SAMOA', 'SAO TOME AND PRINCIPE',
#        'SAUDI ARABIA', 'SENEGAL', 'SERBIA', 'SERBIA AND MONTENEGRO',
#        'SIERRA LEONE', 'SINT EUSTATIUS', 'SINT MAARTEN(DUTCH)',
#        'SLOVAKIA', 'SLOVENIA', 'SOMALIA', 'SOUTH AFRICA', 'SOUTH KOREA',
#        'SOUTH SUDAN', 'SPAIN', 'SRI LANKA', 'ST. KITTS-NEVIS',
#        'ST. LUCIA', 'ST. VINCENT-GRENADINES', 'SUDAN', 'SURINAME',
#        'SWEDEN', 'SWITZERLAND', 'SYRIA', 'TAIWAN', 'TAJIKISTAN',
#        'TANZANIA', 'THAILAND', 'TOGO', 'TONGA', 'TRINIDAD AND TOBAGO',
#        'TUNISIA', 'TURKIYE', 'TURKMENISTAN', 'TURKS AND CAICOS ISLANDS',
#        'UGANDA', 'UKRAINE', 'UNITED ARAB EMIRATES', 'UNITED KINGDOM',
#        'URUGUAY', 'USSR', 'UZBEKISTAN', 'VENEZUELA', 'VIETNAM', 'YEMEN',
#        'YUGOSLAVIA', 'ZAMBIA', 'ZIMBABWE'], dtype=object)

# %% [markdown]
# **Note** - some old countries, and some potential duplication with this.
#
# Examples:
# * `YUGOSLAVIA`
# * `CZECHOSLOVAKIA` and `CZECH REPUBLIC` & `SLOVAKIA`
# * `USSR`
#
# Is it because these were the individual's citizenships at the time they moved to the US?

# %%
arrests_df[arrests_df['Citizenship Country']=='CZECHOSLOVAKIA']['Birth Year']
# Out:
# 167363    1966
# Name: Birth Year, dtype: int64

# %% [markdown]
# ##### 2. `Apprehension Site Landmark`

# %%
np.sort(arrests_df['Apprehension Site Landmark'].fillna('').unique())
# Out:
# array(['', ' ADELANTO DETENTION CENTER (SBSD) ADELANTO, CA',
#        ' LICENSING UNIT/ STATE POLICE', ...,
#        'Z09 - MASTERSON TO MANGANA HEIN TO MCKENDRICK/RIO BRAVO FENCELINE',
#        'ZAPATA COUNTY REGIONAL JAIL', 'ZAVALA COUNTY JAIL'], dtype=object)

# %% [markdown]
# **Note** looks like some whitespace that needs to be cleaned

# %%
arrests_df['Apprehension Site Landmark'].value_counts().head(50)
# Out:
# Apprehension Site Landmark
# DALLAS COUNTY GENERAL AREA                               11105
# MTG GENERAL AREA, NON-SPECIFIC                            9009
# NDD - 26 FEDERAL PLAZA NY, NY                             5805
# HARRIS COUNTY JAIL, HOUSTON, TX                           4713
# LOS ANGELES COUNTY GENERAL AREA, NON-SPECIFIC             4388
# HLG GENERAL AREA, NON-SPECIFIC                            3535
# ATLANTA, GA                                               3442
# SNA GENERAL AREA, NON-SPECIFIC                            3357
# AUS GENERAL AREA, NON-SPECIFIC                            2869
# FUGITIVE OPERATIONS MA                                    2827
# CAP - MARICOPA COUNTY SHERIFFS OFFICE JAIL                2732
# Miramar ICE/ERO Sub-Office                                2465
# WAS GENERAL AREA, NON-SPECIFIC                            2359
# MIAMI DADE COUNTY JAIL TURNER GUILFORD KNIGHT (TGK)       2334
# EDN GENERAL AREA, NON-SPECIFIC                            2227
# ICE ERO NEWARK                                            2141
# SLC GENERAL AREA, NON-SPECIFIC                            2098
# WALKINS AT SAN ANTONIO                                    1999
# DLR GENERAL AREA, NON-SPECIFIC                            1833
# CHI GENERAL AREA, NON-SPECIFIC                            1818
# LRD GENERAL AREA, NON-SPECIFIC                            1771
# ORL GENERAL AREA, NON-SPECIFIC                            1742
# SPM GENERAL AREA, NON-SPECIFIC                            1679
# TEXAS DEPT OF CRIMINAL JUSTICE, WALKER CO                 1637
# INP GENERAL AREA, NON-SPECIFIC                            1519
# DENVER COUNTY                                             1483
# TAL GENERAL AREA, NON-SPECIFIC                            1403
# MIA GENERAL AREA, NON-SPECIFIC                            1383
# TLS GENERAL AREA, NON-SPECIFIC                            1333
# BEXAR COUNTY JAIL - TX0150000                             1271
# MECKLENBURG COUNTY, NC                                    1257
# RCM GENERAL AREA, NON-SPECIFIC                            1233
# Coastal Bend Detention Center                             1186
# STUART                                                    1154
# CIN GENERAL AREA, NON-SPECIFIC                            1125
# Collier County 287g Program                               1089
# SBD GENERAL AREA, NON-SPECIFIC                            1079
# FMY GENERAL AREA, NON-SPECIFIC                            1050
# MARION COUNTY SHERIFF'S OFFICE, INDIANAPOLIS, INDIANA     1022
# OKLAHOMA CITY ICE ERO SUB-OFFICE                          1005
# YAZOO CITY FCI                                            1005
# JAC GENERAL AREA, NON-SPECIFIC                             992
# NSV GENERAL AREA, NON-SPECIFIC                             950
# San Diego, CA                                              936
# SAA GENERAL AREA, NON-SPECIFIC                             925
# BROWARD COUNTY MAIN JAIL                                   906
# EPC GENERAL AREA, NON-SPECIFIC                             899
# CHARLESTON COUNTY, SC                                      891
# DAL COUNTY JAIL                                            885
# TRAVIS COUNTY JAIL(DEL VALLE UNIT) DEL VALLE, TEXAS        877
# Name: count, dtype: int64

# %%
(arrests_df['Apprehension Site Landmark'].value_counts(dropna=False) == 1).sum()
# Out:
# 1216

# %%
arrests_df[arrests_df['Apprehension Site Landmark'].fillna('').str.contains('COUNTY')]['Apprehension Site Landmark'].unique()
# Out:
# array(['HARRIS COUNTY JAIL, HOUSTON, TX',
#        'MIAMI DADE COUNTY JAIL TURNER GUILFORD KNIGHT (TGK)',
#        'TAM-PINELLAS COUNTY JAIL', ..., 'ARCHER COUNTY JAIL',
#        "GOCGEN-GOLIAD COUNTY SHERIFF'S OFFICE", 'CRAWFORD COUNTY, GA'],
#       dtype=object)

# %%
arrests_df[arrests_df['Apprehension Site Landmark'].fillna('').str.contains('287')]['Apprehension Site Landmark'].unique()
# Out:
# array(['Collier County 287g Program', 'CCN GENERAL AREA, CABARRUS 287G',
#        'HALL COUNTY JAIL - 287(G)', 'Benton County Jail 287(g)',
#        'GASTON COUNTY JAIL 287G', 'GCN GENERAL AREA, GASTON 287G',
#        '287(G) - ADC JEO', '287(G) - MESA CITY JAIL JEO',
#        'YORK COUNTY (SC) JAIL 287G', '287(G) - YCSO CAMP VERDE JAIL JEO',
#        "287(G)-CLAY COUNTY SHERIFF'S OFFICE",
#        'Henderson County Jail 287G', 'HEN GENERAL AREA, HENDERSON 287G',
#        'Gaston County Jail 287G', 'GWINNETT COUNTY JAIL - 287(G)',
#        '287(G) PINAL COUNTY JAIL FLORENCE JEO',
#        '287G COLLIER FMY ERO PROGRAM',
#        '287(G) PINAL COUNTY SHERIFF PATROL (TFO)',
#        '287G OFFICER BARNSTABLE COUNTY', 'HENDERSON COUNTY JAIL 287G',
#        'CABARRUS COUNTY JAIL 287G', "287(G)-KNOX COUNTY SHERIFF'S OFFICE",
#        'BENTON COUNTY 287G JAIL ENFORCEMENT OFFICER',
#        'Cabarrus County Jail 287G', 'DOC 287G OFFICER, MCI CONCORD',
#        '287(G) - AZ DOC (JEO)', 'WHITFIELD COUNTY JAIL - 287(G)'],
#       dtype=object)

# %% [markdown]
# ### General variables observations:
# * `Birth Year` and `Citizenship Country` are both complete and have  - key variables that tell us about individual arrested
#    * Remember that `Citizenship Country` doesn't map only to current countries, but is a reflection that the individuals likely moved to the US prior to the dissolution/division of these countries
# * `Apprehension Method` might have some useful info for later - note `287(g) Program` is a variable here
# * `Final Program` has both `287G PROGRAM` and `287G TASK FORCE`
# * `Apprehension Site Landmark`
#     * needs a bit of cleaning: Whitespace; CAPS (some don't seem to be caps, although most are)
#     * very varied in amount of detail and format
#     * some specify the arrest was under the 287g program
