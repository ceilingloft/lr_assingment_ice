# %% [markdown]
# # Task-1 Making sense of the data
#
# One of the reporters asks if you can find Mahmoud Khalil in the dataset. If you do, explain how you identified the correct record in the ICE data, by describing what logic you used, which fields you filtered on, how you handled any ambiguities and what steps you took to be confident it was the right match.

# %% [markdown]
# ## 0. Set up

# %%
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd

import process_data

# %%
arrests_filename = 'arrests-0923-0625.xlsx'
cwd = Path.cwd()
root = cwd.parent
data = root / "data"

# %%
pd.set_option("display.max_rows", 300)

# %%
arrests_df = process_data.read_arrests_data(data/arrests_filename)

# %%
arrests_df.head()
# Out:
#     apprehension_date apprehension_state                   apprehension_aor  \
# 0 2024-08-07 09:43:00           VIRGINIA  WASHINGTON AREA OF RESPONSIBILITY
# 1 2024-10-19 20:33:00              TEXAS     HOUSTON AREA OF RESPONSIBILITY
# 2 2025-04-15 10:08:21         NEW JERSEY      NEWARK AREA OF RESPONSIBILITY
# 3 2025-06-03 09:20:00          MINNESOTA    ST. PAUL AREA OF RESPONSIBILITY
# 4 2025-01-21 17:41:00                NaN       MIAMI AREA OF RESPONSIBILITY
#
#                 final_program        apprehension_method  \
# 0  ERO CRIMINAL ALIEN PROGRAM       NON-CUSTODIAL ARREST
# 1  ERO CRIMINAL ALIEN PROGRAM    CAP LOCAL INCARCERATION
# 2  ERO CRIMINAL ALIEN PROGRAM  CAP FEDERAL INCARCERATION
# 3         FUGITIVE OPERATIONS       NON-CUSTODIAL ARREST
# 4  ERO CRIMINAL ALIEN PROGRAM    CAP LOCAL INCARCERATION
#
#        apprehension_criminality                           case_status  \
# 0          1 CONVICTED CRIMINAL  8-EXCLUDED/REMOVED - INADMISSIBILITY
# 1          1 CONVICTED CRIMINAL    6-DEPORTED/REMOVED - DEPORTABILITY
# 2          1 CONVICTED CRIMINAL  8-EXCLUDED/REMOVED - INADMISSIBILITY
# 3  3 OTHER IMMIGRATION VIOLATOR                                ACTIVE
# 4    2 PENDING CRIMINAL CHARGES       3-VOLUNTARY DEPARTURE CONFIRMED
#
#                                        case_category departed_date  \
# 0                        [16] REINSTATED FINAL ORDER    2024-08-19
# 1                        [16] REINSTATED FINAL ORDER    2024-10-22
# 2                        [16] REINSTATED FINAL ORDER    2025-06-10
# 3    [8G] EXPEDITED REMOVAL - CREDIBLE FEAR REFERRAL           NaT
# 4  [8C] EXCLUDABLE / INADMISSIBLE - ADMINISTRATIV...    2025-02-01
#
#     departure_country final_order_yes_no  birth_year citizenship_country  \
# 0            HONDURAS                YES        1981            HONDURAS
# 1              MEXICO                YES        1984              MEXICO
# 2  DOMINICAN REPUBLIC                YES        1988  DOMINICAN REPUBLIC
# 3                 NaN                YES        1985            COLOMBIA
# 4              MEXICO                YES        1983              MEXICO
#
#    gender                         apprehension_site_landmark  \
# 0    MALE                     HBG GENERAL AREA, NON-SPECIFIC
# 1    MALE                    HARRIS COUNTY JAIL, HOUSTON, TX
# 2    MALE                          FORT DIX EAST, NEW JERSEY
# 3  FEMALE                     SPM GENERAL AREA, NON-SPECIFIC
# 4    MALE  MIAMI DADE COUNTY JAIL TURNER GUILFORD KNIGHT ...
#
#                           unique_identifier
# 0  0000b34edd657d516c02b13a7c352d62d0effcb6
# 1  0000ba6e459998a6046d185d82cf4349de1479d0
# 2  0000c3d23fb0e444864559575900d410c4e8490f
# 3  0000d3dbf8033b5f209f6547ffee5b84feb4f599
# 4  000104d730bf021326c6dc0deb3dd575304136b5

# %% [markdown]
# # Approach:
#
# **Note:** for initial data exploration please see `./0-data_exploration.ipynb`

# %% [markdown]
# ## 1. Choosing what to filter on:
#
# **What information do we know about Mahmoud Khalil that we can use to find him in the dataset?**
#
# Things that have been reported about Mahmoud Khalil:
# * Location of arrest: New York (Columbia University Residence)
# * Year of birth: 1995
# * Citizenship: Algeria (born in Syria to Palestinian parents, and moved to Lebanon)
# * He had a green card (ie not on a tempory visa or undocumented)
# * Time and Date of Arrest: 2025-03-08, around 8.30pm
# * Where was he taken after his arrest? [his own understanding of this was shared in his letter](https://www.newsweek.com/mahmoud-khalil-columbia-hamas-gaza-israel-letter-2047002)
# * * 26 Federal Plaza - on the 8th March (?)
#   * Elizabeth Detention Centre, New Jersey - taken in the early hours of the 9th (NB when his wife tried to find him there on the 9th she was told he was not there, so there are some question marks over this)
#   * ICE detention center in Louisiana

# %% [markdown]
# ### Finding the relevant variables:

# %%
birth_1995 = arrests_df['birth_year'] == 1995
citizenship_algeria = arrests_df['citizenship_country'] == 'ALGERIA' # might need to try out SYRIA and LEBANON here (although I don't think he has citizenship)

# %%
unique_vars_filter_str = lambda col, str_match: arrests_df[col][arrests_df[col].fillna('').str.contains(str_match)].unique()

# %% [markdown]
# #### Locations
#
# ##### 1. Arrest location = New York, initially taken to 26 Federal Plaza

# %%
np.sort(arrests_df['apprehension_state'].fillna('').unique())
# Out:
# array(['', 'ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS',
#        'ARMED FORCES - EUROPE', 'ARMED FORCES - THE AMERICAS',
#        'ARMED SERVICES - PACIFIC', 'CALIFORNIA', 'COLORADO',
#        'CONNECTICUT', 'DELAWARE', 'DISTRICT OF COLUMBIA',
#        'FEDERATED STATES OF MICRONESIA', 'FLORIDA', 'GEORGIA', 'GUAM',
#        'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS',
#        'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARYLAND', 'MASSACHUSETTS',
#        'MEXICO', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI', 'MISSOURI',
#        'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY',
#        'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA', 'NORTH DAKOTA',
#        'NORTHERN MARIANA ISLANDS', 'OHIO', 'OKLAHOMA', 'OREGON',
#        'PENNSYLVANIA', 'PUERTO RICO', 'RHODE ISLAND', 'SOUTH CAROLINA',
#        'SOUTH DAKOTA', 'TAMAULIPAS', 'TENNESSEE', 'TEXAS', 'UTAH',
#        'VERMONT', 'VIRGIN ISLANDS', 'VIRGINIA', 'WASHINGTON',
#        'WEST VIRGINIA', 'WISCONSIN', 'WYOMING'], dtype=object)

# %%
unique_vars_filter_str('apprehension_site_landmark','26 FEDERAL')
# Out:
# array(['NDD - 26 FEDERAL PLAZA NY, NY'], dtype=object)

# %%
arrests_df[arrests_df['apprehension_site_landmark']=='NDD - 26 FEDERAL PLAZA NY, NY']['apprehension_state'].value_counts(dropna=False)
# Out:
# apprehension_state
# NEW YORK          5646
# NaN                151
# NORTH CAROLINA       4
# NEW JERSEY           1
# FLORIDA              1
# Name: count, dtype: int64

# %% [markdown]
# **Observations:**
# * Looks like that is the correct site for 26 Federal Plaza, NY
# * But note - not all who have `'apprehension_site_landmark' == 'NDD - 26 FEDERAL PLAZA NY, NY'` have `'apprehension_state' == 'NEW YORK'`
#    * Maybe taken to be processed at 26 Federal Plaza after being initially arrested in the location? But Florida and North Carolina are quite a long way
#    * 151 with missing `apprehension_state`

# %%
state_ny = arrests_df['apprehension_state'] == 'NEW YORK' 
state_missing = arrests_df['apprehension_state'].isna() # NB - from initial data exploration we know this has quite a lot of missing, so don't rely on it being added
loc_federal_plaza = arrests_df['apprehension_site_landmark'] == 'NDD - 26 FEDERAL PLAZA NY, NY'

# %% [markdown]
# ##### 2. Taken to: Elizabeth Detention Center in New Jersey and ICE Detention Center in Louisiana
#
# Doesn't look like these are in this dataset, which makes sense because this is arrests, not detentions:

# %%
unique_vars_filter_str('apprehension_site_landmark','ELIZABETH')
# Out:
# array(['ELIZABETH CITY', 'ELIZABETH PD'], dtype=object)

# %%
unique_vars_filter_str('apprehension_site_landmark','LOUISIANA')
# Out:
# array(['LOUISIANA STATE PENITENTIARY - ANGOLA'], dtype=object)

# %% [markdown]
# #### 2. Apprehension date

# %%
get_date = lambda date_str: datetime.strptime(date_str, '%Y-%m-%d').date()

# %%
def filter_dates(df, start_date, eq=True, end_date=None, date_col='apprehension_date'):
    if end_date:
        return (df[date_col].dt.date >= get_date(start_date)) & (df[date_col].dt.date <= get_date(end_date))
    elif eq:
        return df[date_col].dt.date == get_date(start_date)
    else:
        return df[date_col].dt.date >= get_date(start_date)

# %%
arrests_df[filter_dates(arrests_df, '2025-03-08')]
# Out:
#          apprehension_date apprehension_state  \
# 429    2025-03-08 22:05:00              TEXAS
# 1801   2025-03-08 08:53:00            FLORIDA
# 4209   2025-03-08 23:36:00            GEORGIA
# 6619   2025-03-08 09:47:00         WASHINGTON
# 6848   2025-03-08 07:13:00              TEXAS
# ...                    ...                ...
# 264332 2025-03-08 04:39:00              TEXAS
# 264333 2025-03-08 09:50:11              TEXAS
# 264334 2025-03-08 07:54:37              TEXAS
# 264335 2025-03-08 09:47:51              TEXAS
# 264336 2025-03-08 09:51:28              TEXAS
#
#                         apprehension_aor                final_program  \
# 429       HOUSTON AREA OF RESPONSIBILITY   ERO CRIMINAL ALIEN PROGRAM
# 1801        MIAMI AREA OF RESPONSIBILITY   ERO CRIMINAL ALIEN PROGRAM
# 4209      ATLANTA AREA OF RESPONSIBILITY                 287G PROGRAM
# 6619      SEATTLE AREA OF RESPONSIBILITY  NON-DETAINED DOCKET CONTROL
# 6848    HARLINGEN AREA OF RESPONSIBILITY   ERO CRIMINAL ALIEN PROGRAM
# ...                                  ...                          ...
# 264332     DALLAS AREA OF RESPONSIBILITY          FUGITIVE OPERATIONS
# 264333  HARLINGEN AREA OF RESPONSIBILITY  NON-DETAINED DOCKET CONTROL
# 264334  HARLINGEN AREA OF RESPONSIBILITY   ERO CRIMINAL ALIEN PROGRAM
# 264335  HARLINGEN AREA OF RESPONSIBILITY      DETAINED DOCKET CONTROL
# 264336  HARLINGEN AREA OF RESPONSIBILITY   ERO CRIMINAL ALIEN PROGRAM
#
#               apprehension_method      apprehension_criminality  \
# 429       CAP LOCAL INCARCERATION    2 PENDING CRIMINAL CHARGES
# 1801                      LOCATED  3 OTHER IMMIGRATION VIOLATOR
# 4209               287(G) PROGRAM    2 PENDING CRIMINAL CHARGES
# 6619                      LOCATED          1 CONVICTED CRIMINAL
# 6848    CAP FEDERAL INCARCERATION  3 OTHER IMMIGRATION VIOLATOR
# ...                           ...                           ...
# 264332       NON-CUSTODIAL ARREST  3 OTHER IMMIGRATION VIOLATOR
# 264333    CAP LOCAL INCARCERATION  3 OTHER IMMIGRATION VIOLATOR
# 264334    CAP LOCAL INCARCERATION    2 PENDING CRIMINAL CHARGES
# 264335                    LOCATED    2 PENDING CRIMINAL CHARGES
# 264336    CAP LOCAL INCARCERATION    2 PENDING CRIMINAL CHARGES
#
#                                  case_status  \
# 429     8-EXCLUDED/REMOVED - INADMISSIBILITY
# 1801    8-EXCLUDED/REMOVED - INADMISSIBILITY
# 4209    8-EXCLUDED/REMOVED - INADMISSIBILITY
# 6619      6-DEPORTED/REMOVED - DEPORTABILITY
# 6848      6-DEPORTED/REMOVED - DEPORTABILITY
# ...                                      ...
# 264332                                   NaN
# 264333                        9-VR WITNESSED
# 264334                        9-VR WITNESSED
# 264335                        9-VR WITNESSED
# 264336                        9-VR WITNESSED
#
#                                             case_category departed_date  \
# 429     [8C] EXCLUDABLE / INADMISSIBLE - ADMINISTRATIV...    2025-05-03
# 1801                          [16] REINSTATED FINAL ORDER    2025-03-18
# 4209    [8C] EXCLUDABLE / INADMISSIBLE - ADMINISTRATIV...    2025-05-12
# 6619                          [16] REINSTATED FINAL ORDER    2025-06-03
# 6848                          [16] REINSTATED FINAL ORDER    2025-03-12
# ...                                                   ...           ...
# 264332                                                NaN           NaT
# 264333                            [9] VR UNDER SAFEGUARDS    2025-03-09
# 264334                            [9] VR UNDER SAFEGUARDS    2025-03-08
# 264335                            [9] VR UNDER SAFEGUARDS    2025-03-08
# 264336                            [9] VR UNDER SAFEGUARDS    2025-03-08
#
#        departure_country final_order_yes_no  birth_year citizenship_country  \
# 429            GUATEMALA                YES        2002           GUATEMALA
# 1801           GUATEMALA                YES        1988           GUATEMALA
# 4209           NICARAGUA                YES        1996           NICARAGUA
# 6619              MEXICO                YES        1984              MEXICO
# 6848           GUATEMALA                YES        1995           GUATEMALA
# ...                  ...                ...         ...                 ...
# 264332               NaN                NaN        1986            HONDURAS
# 264333            MEXICO                 NO        2003              MEXICO
# 264334            MEXICO                 NO        1994              MEXICO
# 264335            MEXICO                 NO        2005              MEXICO
# 264336            MEXICO                 NO        1995              MEXICO
#
#         gender                 apprehension_site_landmark  \
# 429       MALE            HARRIS COUNTY JAIL, HOUSTON, TX
# 1801      MALE    ORL - OSCEOLA COUNTY JAIL FLORIDA STATE
# 4209      MALE             DTN GENERAL AREA, NON-SPECIFIC
# 6619      MALE                            SEATTLE FUG OPS
# 6848    FEMALE              COASTAL BEND DETENTION CENTER
# ...        ...                                        ...
# 264332    MALE  N DIST TX LUBBOCK DIV LUBBOCK CO NON CRIM
# 264333    MALE             HLG GENERAL AREA, NON-SPECIFIC
# 264334    MALE            CAMERON COUNTY JAIL- OLMITO, TX
# 264335    MALE             LRD GENERAL AREA, NON-SPECIFIC
# 264336    MALE             HLG GENERAL AREA, NON-SPECIFIC
#
#                                unique_identifier
# 429     0068cbef972a10a35f635b938da93b004b0e8363
# 1801    01bb776414fe6dd08384c3607f89f2527587afbb
# 4209    041cb3841e8124f1b2e9fb5a4014c48178bafa64
# 6619    067e9f4a30f1d622088ba0ae32409d3bbd00a6a4
# 6848    06b47e14d010e63a5e03fc9c5945486dbcebed87
# ...                                          ...
# 264332                                       NaN
# 264333                                       NaN
# 264334                                       NaN
# 264335                                       NaN
# 264336                                       NaN
#
# [334 rows x 16 columns]

# %% [markdown]
# #### 3. Immigration status
#
# According to the documentation, Unique Identifier is based on Alien Registration Number (A-number). As Mahmoud Khalil had a green card, we might assume he would not have an A-number, and therefore wouldn't have a Unique Identifier. This is a big assumption though, and the ICE enforcement agents did think he had a student visa, so he might have an A-number from before he had a green card?

# %%
no_ui = arrests_df['unique_identifier'].isna()

# %% [markdown]
# Are there any other clues in other variables that indicate immigration status?

# %%
arrests_df['final_program'].value_counts()
# Out:
# final_program
# ERO CRIMINAL ALIEN PROGRAM             162433
# FUGITIVE OPERATIONS                     39776
# NON-DETAINED DOCKET CONTROL             33165
# ALTERNATIVES TO DETENTION               12761
# DETAINED DOCKET CONTROL                  8972
# 287G PROGRAM                             4934
# MOBILE CRIMINAL ALIEN TEAM               2214
# JUVENILE                                  444
# ERO CRIMINAL PROSECUTIONS                 304
# DETENTION AND DEPORTATION                 159
# LAW ENFORCEMENT AREA RESPONSE UNITS        45
# 287G TASK FORCE                            10
# VIOLENT CRIMINAL ALIEN SECTION              5
# JOINT CRIMINAL ALIEN RESPONSE TEAM          4
# Name: count, dtype: int64

# %%
arrests_df['apprehension_method'].value_counts()
# Out:
# apprehension_method
# CAP LOCAL INCARCERATION                        112103
# NON-CUSTODIAL ARREST                            56910
# LOCATED                                         31405
# CAP FEDERAL INCARCERATION                       23408
# CAP STATE INCARCERATION                         10419
# OTHER EFFORTS                                    9018
# ERO REPROCESSED ARREST                           8875
# 287(G) PROGRAM                                   6313
# PROBATION AND PAROLE                             3833
# LAW ENFORCEMENT AGENCY RESPONSE UNIT              845
# OTHER TASK FORCE                                  505
# PATROL BORDER                                     477
# OTHER AGENCY (TURNED OVER TO INS)                 444
# WORKSITE ENFORCEMENT                              252
# INSPECTIONS                                       127
# ANTI-SMUGGLING                                     84
# TRAFFIC CHECK                                      62
# ORGANIZED CRIME DRUG ENFORCEMENT TASK FORCE        52
# PATROL INTERIOR                                    51
# BOAT PATROL                                        14
# TRANSPORTATION CHECK AIRCRAFT                      13
# CREWMAN/STOWAWAY                                    5
# TRANSPORTATION CHECK BUS                            5
# CRIMINAL ALIEN PROGRAM                              4
# TRANSPORTATION CHECK PASSENGER TRAIN                2
# Name: count, dtype: int64

# %%
mk_key_columns=['apprehension_date','apprehension_state','birth_year','citizenship_country','gender','apprehension_site_landmark']

# %% [markdown]
# Potentially useful info in Final Program, but would have to do some more research to clarify meaning of some of the categories

# %% [markdown]
# ## 2. Filtering - trying to find Mahmoud Khalil

# 90799               CAP - MARICOPA COUNTY SHERIFFS OFFICE
# 154443                                                NaN
# 98054                      MTG GENERAL AREA, NON-SPECIFIC
# 131875                     MTG GENERAL AREA, NON-SPECIFIC
# 262017                     MTG GENERAL AREA, NON-SPECIFIC
# 52308                      MTG GENERAL AREA, NON-SPECIFIC
# 44430   LIMESTONE COUNTY DETENTION CENTER, GROESBECK, ...
# 154545                     MTG GENERAL AREA, NON-SPECIFIC
# 250929                     MTG GENERAL AREA, NON-SPECIFIC
# 122169                                FARMERS BRANCH JAIL
# 60537                         ARLINGTON POLICE DEPARTMENT
# 4505                         FORT WORTH POLICE DEPARTMENT
# 30262                        SMITH COUNTY SHERIFFS OFFICE
# 42620                      CIN GENERAL AREA, NON-SPECIFIC
# 97102                                                 NaN
# 61307                                                 NaN
# 36294                          DALLAS COUNTY GENERAL AREA
# 56503                                              STUART
# 136230                     IMP GENERAL AREA, NON-SPECIFIC
# 197863                     MID GENERAL AREA, NON-SPECIFIC
# 40301   MIAMI DADE COUNTY JAIL TURNER GUILFORD KNIGHT ...
# 173133                         DALLAS COUNTY GENERAL AREA
# 10039   MIAMI DADE COUNTY JAIL TURNER GUILFORD KNIGHT ...
# 237469                     PHI GENERAL AREA, NON-SPECIFIC
# 14436                                   STARK COUNTY JAIL
# 181361                             FUGITIVE OPERATIONS MA
# 172921                         DALLAS COUNTY GENERAL AREA
# 115133                                   WAKE COUNTY JAIL
# 31117                            STL GENERAL NON-SPECIFIC
# 140140                               STUART-STREET ARREST
# 65095                                STUART-STREET ARREST
# 184131                     PIT GENERAL AREA, NON-SPECIFIC
# 191838            MONTGOMERY COUNTY CORRECTIONAL FACILITY
# 127903                         DALLAS COUNTY GENERAL AREA
# 9014                           DALLAS COUNTY GENERAL AREA
# 78885                          DALLAS COUNTY GENERAL AREA
# 138427                         DALLAS COUNTY GENERAL AREA
# 207992                         DALLAS COUNTY GENERAL AREA
# 169345                             CAP - GILA COUNTY JAIL

# %% [markdown]
# **Summary:** There does not seem to be a clear match for either location field around the timeframe.
#
# ### 2. Demographics
#
# #### Citizenship == Algeria, and Birth Year is 1995:

# %%
arrests_df[citizenship_algeria & birth_1995][mk_key_columns]
# Out:
#          apprehension_date apprehension_state  birth_year citizenship_country  \
# 107560 2025-03-11 12:56:29           NEW YORK        1995             ALGERIA
#
#        gender       apprehension_site_landmark
# 107560   MALE  SING SING CORRECTIONAL FACILITY

# %% [markdown]
# ### Could this be Mahmoud Khalil?
#
# **Headline:** I think it is unlikely. While there are some clear similarities, there are important inconsistancies that don't fit what has been stated in the media, and by Mahmoud Khalil himself, about the case.
#
# Evidence in support:
# * Apprehension in New York close to the time Mahmoud Khalil was arrested
# * Demographic match - Citizenship is Algerian, and Birth Year is 1995
#
# Evidence against:
# * Apprehension site landmark is Sing Sing Correctional Facility, which is a prison in upstate New York. There is no reporting or other evidence to suggest Mahmoud Khalil was taken to Sing Sing, and the timeframe does not really allow for it (he was stated to be in Louisiana around the same time)
# * Apprehension method is "CAP STATE INCARCERATION" - CAP is Criminal Alien Program ([source: ICE.gov](https://www.ice.gov/identify-and-arrest/criminal-alien-program)), and "CAP STATE INCARCERATION" suggests this is an example of someone already incarcerated being arrested by ICE
